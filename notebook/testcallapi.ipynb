# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from flask import Flask, jsonify
import pyodbc
import psycopg2

# %%
conn = psycopg2.connect("dbname=Project2_db user=postgres password=TRG19_sustain port=6969")

# %%
cursor1 = conn.cursor()
cursor1.execute('SELECT * FROM supercharged')
for row in cursor1:
    print(row)
# Out:
# (1, 'USA', 'Mebane', 'OPEN', datetime.date(2021, 1, 27), Decimal('36.070176'), Decimal('-79.270532'))
# (2, 'Norway', 'Kvalsund', 'OPEN', datetime.date(2021, 1, 27), Decimal('70.431958'), Decimal('24.506893'))
# (3, 'USA', 'Torrance', 'OPEN', datetime.date(2021, 1, 22), Decimal('33.834811'), Decimal('-118.349039'))
# (4, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.918406'), Decimal('116.282413'))
# (5, 'China', 'Guangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('23.076611'), Decimal('113.319826'))
# (6, 'China', 'Guangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('23.147219'), Decimal('113.382671'))
# (7, 'China', 'Cangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('38.310492'), Decimal('116.819753'))
# (8, 'China', 'Changsha', 'OPEN', datetime.date(2021, 1, 22), Decimal('28.353669'), Decimal('112.986119'))
# (9, 'China', 'Zhoushan', 'OPEN', datetime.date(2021, 1, 22), Decimal('29.972572'), Decimal('122.32252'))
# (10, 'China', 'Changsha', 'OPEN', datetime.date(2021, 1, 22), Decimal('28.118471'), Decimal('113.002371'))
# (11, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.279558'), Decimal('120.143642'))
# (12, 'China', 'Wuxi', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.559952'), Decimal('120.315698'))
# (13, 'China', 'Dalian', 'OPEN', datetime.date(2021, 1, 22), Decimal('38.882793'), Decimal('121.692027'))
# (14, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.241554'), Decimal('120.263024'))
# (15, 'China', "Xi'an", 'OPEN', datetime.date(2021, 1, 22), Decimal('34.230591'), Decimal('108.894146'))
# (16, 'China', 'Chengdu', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.657641'), Decimal('104.073464'))
# (17, 'China', 'Leshan', 'OPEN', datetime.date(2021, 1, 22), Decimal('29.569053'), Decimal('103.451858'))
# (18, 'China', 'Tianjin', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.099381'), Decimal('117.126363'))
# (19, 'China', 'Shaoxing', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.006245'), Decimal('120.609766'))
# (20, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.319473'), Decimal('120.171229'))
# (21, 'China', 'Nanjing', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.980275'), Decimal('118.781667'))
# (22, 'China', 'Nanjing', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.981574'), Decimal('118.767322'))
# (23, 'China', 'Jinan', 'OPEN', datetime.date(2021, 1, 22), Decimal('36.713286'), Decimal('116.963366'))
# (24, 'China', 'Kunming', 'OPEN', datetime.date(2021, 1, 22), Decimal('25.032645'), Decimal('102.718044'))
# (25, 'China', 'Shenzhen', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.539001'), Decimal('113.991186'))
# (26, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.250775'), Decimal('121.545518'))
# (27, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.180355'), Decimal('121.379942'))
# (28, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.405354'), Decimal('121.49185'))
# (29, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('40.000287'), Decimal('116.463298'))
# (30, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('40.133427'), Decimal('116.615275'))
# (31, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.692635'), Decimal('116.326798'))
# (32, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.930414'), Decimal('116.606086'))
# (33, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.946298'), Decimal('116.438603'))
# (34, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('40.013789'), Decimal('116.396086'))
# (35, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.91488'), Decimal('116.481841'))
# (36, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.915712'), Decimal('116.379579'))
# (37, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.228966'), Decimal('121.45445'))
# (38, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.134052'), Decimal('120.089615'))
# (39, 'China', 'Nanjing', 'OPEN', datetime.date(2021, 1, 22), Decimal('32.008454'), Decimal('118.731297'))
# (40, 'China', 'Zhengzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('34.763696'), Decimal('113.776627'))
# (41, 'China', 'Guiyang', 'OPEN', datetime.date(2021, 1, 22), Decimal('26.61127'), Decimal('106.726772'))
# (42, 'China', 'Shenzhen', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.718168'), Decimal('113.861517'))
# (43, 'China', 'Haikou', 'OPEN', datetime.date(2021, 1, 22), Decimal('19.992449'), Decimal('110.34916'))
# (44, 'China', 'Chengdu', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.488587'), Decimal('104.101148'))
# (45, 'China', 'Ankang', 'OPEN', datetime.date(2021, 1, 22), Decimal('32.697784'), Decimal('109.030447'))
# (46, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.751717'), Decimal('116.147136'))
# (47, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('40.150571'), Decimal('116.609561'))
# (48, 'China', 'Wenzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('28.048853'), Decimal('120.862025'))
# (49, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.285578'), Decimal('121.173937'))
# (50, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.156717'), Decimal('121.236863'))
# (51, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.272788'), Decimal('120.15048'))
# (52, 'China', 'Zhuhai', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.379412'), Decimal('113.567859'))
# (53, 'China', 'Wanning', 'OPEN', datetime.date(2021, 1, 22), Decimal('18.678209'), Decimal('110.361979'))
# (54, 'China', 'Shenzhen', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.612048'), Decimal('114.068727'))
# (55, 'China', 'Guangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('23.062345'), Decimal('113.305331'))
# (56, 'China', 'Shenzhen', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.638667'), Decimal('114.137622'))
# (57, 'China', 'Guangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('23.013109'), Decimal('113.359129'))
# (58, 'China', 'Ningbo', 'OPEN', datetime.date(2021, 1, 22), Decimal('29.955014'), Decimal('121.607438'))
# (59, 'China', 'Chongqing', 'OPEN', datetime.date(2021, 1, 22), Decimal('29.648169'), Decimal('106.554915'))
# (60, 'China', 'Nanjing', 'OPEN', datetime.date(2021, 1, 22), Decimal('32.091944'), Decimal('118.818111'))
# (61, 'China', 'Xiamen', 'OPEN', datetime.date(2021, 1, 22), Decimal('24.481032'), Decimal('118.118066'))
# (62, 'China', 'Shenzhen', 'OPEN', datetime.date(2021, 1, 22), Decimal('22.662343'), Decimal('114.083533'))
# (63, 'China', 'Changsha', 'OPEN', datetime.date(2021, 1, 22), Decimal('28.257408'), Decimal('112.98579'))
# (64, 'China', 'Guangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('23.088676'), Decimal('113.285731'))
# (65, 'China', 'Shanghai', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.217544'), Decimal('121.483284'))
# (66, 'China', 'Qingdao', 'OPEN', datetime.date(2021, 1, 22), Decimal('36.096741'), Decimal('120.385897'))
# (67, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.284801'), Decimal('120.160432'))
# (68, 'China', 'Chengdu', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.538015'), Decimal('104.103917'))
# (69, 'China', 'Kunming', 'OPEN', datetime.date(2021, 1, 22), Decimal('25.058014'), Decimal('102.746582'))
# (70, 'China', 'Chengdu', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.583752'), Decimal('104.247186'))
# (71, 'China', 'Beijing', 'OPEN', datetime.date(2021, 1, 22), Decimal('39.895152'), Decimal('116.66517'))
# (72, 'China', "Xi'an", 'OPEN', datetime.date(2021, 1, 22), Decimal('34.19896'), Decimal('108.887329'))
# (73, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.303073'), Decimal('120.22139'))
# (74, 'China', 'Hangzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('30.32526'), Decimal('120.115646'))
# (75, 'China', 'Suzhou', 'OPEN', datetime.date(2021, 1, 22), Decimal('31.325766'), Decimal('120.716628'))
# (76, 'Canada', 'Collingwood', 'OPEN', datetime.date(2021, 1, 21), Decimal('44.50884'), Decimal('-80.238819'))
# (77, 'Taiwan', 'Yilan County', 'OPEN', datetime.date(2021, 1, 20), Decimal('24.7476826'), Decimal('121.7629552'))
# (78, 'Taiwan', 'Taipei City', 'OPEN', datetime.date(2021, 1, 20), Decimal('25.056849'), Decimal('121.614709'))
# (79, 'USA', 'Davis', 'OPEN', datetime.date(2021, 1, 20), Decimal('38.542553'), Decimal('-121.725827'))
# (80, 'Canada', 'Bancroft', 'OPEN', datetime.date(2021, 1, 15), Decimal('45.084313'), Decimal('-77.861116'))
# (81, 'USA', 'Concord', 'OPEN', datetime.date(2021, 1, 15), Decimal('37.969947'), Decimal('-122.058491'))
# (82, 'USA', 'Tappahannock', 'OPEN', datetime.date(2021, 1, 14), Decimal('37.903836'), Decimal('-76.865734'))
# (83, 'USA', 'Rehoboth Beach', 'OPEN', datetime.date(2021, 1, 7), Decimal('38.712542'), Decimal('-75.10381'))
# (84, 'France', 'Nice', 'OPEN', datetime.date(2021, 1, 7), Decimal('43.727745'), Decimal('7.186437'))
# (85, 'USA', 'San Mateo', 'OPEN', datetime.date(2021, 1, 6), Decimal('37.533306'), Decimal('-122.327472'))
# (86, 'USA', 'Wells', 'OPEN', datetime.date(2021, 1, 2), Decimal('41.101369'), Decimal('-114.956259'))
# (87, 'USA', 'Goldsboro', 'OPEN', datetime.date(2020, 12, 31), Decimal('35.386452'), Decimal('-77.948309'))
# (88, 'USA', 'Salem', 'OPEN', datetime.date(2020, 12, 31), Decimal('37.271756'), Decimal('-80.037063'))
# (89, 'China', 'Shanghai', 'OPEN', datetime.date(2020, 12, 30), Decimal('31.244585'), Decimal('121.452911'))
# (90, 'USA', 'Hagerstown', 'OPEN', datetime.date(2020, 12, 30), Decimal('39.608895'), Decimal('-77.750802'))
# (91, 'Canada', 'Princeton', 'OPEN', datetime.date(2020, 12, 26), Decimal('49.457882'), Decimal('-120.506224'))
# (92, 'USA', 'Irvine', 'OPEN', datetime.date(2020, 12, 26), Decimal('33.684357'), Decimal('-117.851746'))
# (93, 'Canada', 'Canmore', 'OPEN', datetime.date(2020, 12, 26), Decimal('51.096694'), Decimal('-115.35779'))
# (94, 'Germany', 'München', 'OPEN', datetime.date(2020, 12, 24), Decimal('48.147904'), Decimal('11.465776'))
# (95, 'United Arab Emirates', 'Dubai', 'OPEN', datetime.date(2020, 12, 24), Decimal('24.913898'), Decimal('54.961102'))
# (96, 'USA', 'Granada Hills', 'OPEN', datetime.date(2020, 12, 24), Decimal('34.266172'), Decimal('-118.524155'))
# (97, 'China', 'Tsing Yi', 'OPEN', datetime.date(2020, 12, 23), Decimal('22.362093'), Decimal('114.102924'))
# (98, 'USA', 'Cedar City', 'OPEN', datetime.date(2020, 12, 23), Decimal('37.606299'), Decimal('-113.161244'))
# (99, 'Germany', 'Nürburg', 'OPEN', datetime.date(2020, 12, 23), Decimal('50.331382'), Decimal('6.945171'))
# (100, 'China', 'Urumqi', 'OPEN', datetime.date(2020, 12, 23), Decimal('43.87979'), Decimal('87.57623'))
# (101, 'USA', 'Entiat', 'OPEN', datetime.date(2020, 12, 23), Decimal('47.684662'), Decimal('-120.206959'))
# (102, 'Germany', 'Weibersbrunn', 'OPEN', datetime.date(2020, 12, 23), Decimal('49.934792'), Decimal('9.353691'))
# (103, 'USA', 'Knoxville', 'OPEN', datetime.date(2020, 12, 22), Decimal('35.959109'), Decimal('-83.916658'))
# (104, 'Austria', 'Asten', 'OPEN', datetime.date(2020, 12, 22), Decimal('48.2212'), Decimal('14.407208'))
# (105, 'Germany', 'Lippetal', 'OPEN', datetime.date(2020, 12, 22), Decimal('51.695531'), Decimal('7.96733'))
# (106, 'USA', 'Montrose', 'OPEN', datetime.date(2020, 12, 18), Decimal('38.481242'), Decimal('-107.876472'))
# (107, 'France', 'Vouillé', 'OPEN', datetime.date(2020, 12, 18), Decimal('46.298292'), Decimal('-0.375188'))
# (108, 'Australia', 'Harwood', 'OPEN', datetime.date(2020, 12, 18), Decimal('-29.426979'), Decimal('153.239215'))
# (109, 'USA', 'Williamsburg', 'OPEN', datetime.date(2020, 12, 18), Decimal('37.266487'), Decimal('-76.676613'))
# (110, 'Germany', 'Erharting', 'OPEN', datetime.date(2020, 12, 18), Decimal('48.282736'), Decimal('12.554843'))
# (111, 'USA', 'Winter Garden', 'OPEN', datetime.date(2020, 12, 18), Decimal('28.551646'), Decimal('-81.584416'))
# (112, 'Norway', 'Notodden', 'OPEN', datetime.date(2020, 12, 17), Decimal('59.566378'), Decimal('9.219203'))
# (113, 'Italy', 'Arese', 'OPEN', datetime.date(2020, 12, 17), Decimal('45.563508'), Decimal('9.052541'))
# (114, 'USA', 'Malibu', 'OPEN', datetime.date(2020, 12, 17), Decimal('34.036024'), Decimal('-118.684095'))
# (115, 'United Kingdom', 'Edinburgh', 'OPEN', datetime.date(2020, 12, 17), Decimal('55.93391'), Decimal('-3.407749'))
# (116, 'USA', 'Greenbrae', 'OPEN', datetime.date(2020, 12, 16), Decimal('37.944776'), Decimal('-122.522706'))
# (117, 'United Kingdom', 'Crawley', 'OPEN', datetime.date(2020, 12, 16), Decimal('51.135183'), Decimal('-0.191314'))
# (118, 'Norway', 'Vestby', 'OPEN', datetime.date(2020, 12, 16), Decimal('59.602863'), Decimal('10.741169'))
# (119, 'Netherlands', 'Meerkerk', 'OPEN', datetime.date(2020, 12, 16), Decimal('51.899615'), Decimal('4.982857'))
# (120, 'Sweden', 'Jokkmokk', 'OPEN', datetime.date(2020, 12, 15), Decimal('66.605666'), Decimal('19.824713'))
# (121, 'USA', 'Millstone', 'OPEN', datetime.date(2020, 12, 15), Decimal('40.15767'), Decimal('-74.430151'))
# (122, 'USA', 'Greenfield', 'OPEN', datetime.date(2020, 12, 15), Decimal('36.32925'), Decimal('-121.245444'))
# (123, 'USA', 'Glen Mills', 'OPEN', datetime.date(2020, 12, 14), Decimal('39.883186'), Decimal('-75.534198'))
# (124, 'USA', 'Petersburg', 'OPEN', datetime.date(2020, 12, 12), Decimal('37.1906'), Decimal('-77.3663'))
# (125, 'USA', 'Montauk', 'OPEN', datetime.date(2020, 12, 11), Decimal('41.035822'), Decimal('-71.943868'))
# (126, 'USA', 'Riverhead', 'OPEN', datetime.date(2020, 12, 11), Decimal('40.923322'), Decimal('-72.702788'))
# (127, 'Japan', 'Kawaguchi', 'OPEN', datetime.date(2020, 12, 11), Decimal('35.832459'), Decimal('139.735628'))
# (128, 'USA', 'Seattle', 'OPEN', datetime.date(2020, 12, 11), Decimal('47.662639'), Decimal('-122.374975'))
# (129, 'France', 'Sainte-Hermine', 'OPEN', datetime.date(2020, 12, 11), Decimal('46.5732276'), Decimal('-1.117874'))
# (130, 'USA', 'Lexington', 'OPEN', datetime.date(2020, 12, 10), Decimal('35.800189'), Decimal('-80.288565'))
# (131, 'United Kingdom', 'Aberdeen', 'OPEN', datetime.date(2020, 12, 10), Decimal('57.1103'), Decimal('-2.0925'))
# (132, 'Sweden', 'Kristinehamn', 'OPEN', datetime.date(2020, 12, 9), Decimal('59.314807'), Decimal('14.147564'))
# (133, 'Germany', 'Knetzgau', 'OPEN', datetime.date(2020, 12, 9), Decimal('49.981648'), Decimal('10.554985'))
# (134, 'United Kingdom', 'Banbury', 'OPEN', datetime.date(2020, 12, 8), Decimal('52.073571'), Decimal('-1.342005'))
# (135, 'New Zealand', 'Mount Wellington', 'OPEN', datetime.date(2020, 12, 8), Decimal('-36.914103'), Decimal('174.840171'))
# (136, 'USA', 'Lisbon', 'OPEN', datetime.date(2020, 12, 8), Decimal('41.58569'), Decimal('-71.991059'))
# (137, 'United Kingdom', 'Springfield, Chelmsford', 'OPEN', datetime.date(2020, 12, 8), Decimal('51.7503'), Decimal('0.5114'))
# (138, 'USA', 'Seattle', 'OPEN', datetime.date(2020, 12, 7), Decimal('47.6066581'), Decimal('-122.3371498'))
# (139, 'USA', 'Peachtree Corners', 'OPEN', datetime.date(2020, 12, 4), Decimal('33.978802'), Decimal('-84.214918'))
# (140, 'USA', 'Irvine', 'OPEN', datetime.date(2020, 12, 4), Decimal('33.689828'), Decimal('-117.769439'))
# (141, 'United Kingdom', 'Braintree', 'OPEN', datetime.date(2020, 12, 4), Decimal('51.8526'), Decimal('0.5224'))
# (142, 'Slovakia', 'Košice', 'OPEN', datetime.date(2020, 12, 3), Decimal('48.695112'), Decimal('21.235596'))
# (143, 'New Zealand', 'Whangarei', 'OPEN', datetime.date(2020, 12, 2), Decimal('-35.725282'), Decimal('174.31861'))
# (144, 'Germany', 'Ellwangen', 'OPEN', datetime.date(2020, 12, 1), Decimal('48.959165'), Decimal('10.173534'))
# (145, 'Austria', 'Biberwier', 'OPEN', datetime.date(2020, 11, 30), Decimal('47.372431'), Decimal('10.886093'))
# (146, 'China', 'Tuen Mun', 'OPEN', datetime.date(2020, 11, 28), Decimal('22.396887'), Decimal('113.968827'))
# (147, 'Norway', 'Leira i Valdres', 'OPEN', datetime.date(2020, 11, 27), Decimal('60.969587'), Decimal('9.29115'))
# (148, 'USA', 'Washington DC', 'OPEN', datetime.date(2020, 11, 26), Decimal('38.92225'), Decimal('-76.953333'))
# (149, 'USA', 'Gilroy', 'OPEN', datetime.date(2020, 11, 26), Decimal('37.000817'), Decimal('-121.554338'))
# (150, 'USA', 'St. George', 'OPEN', datetime.date(2020, 11, 25), Decimal('37.077652'), Decimal('-113.583912'))
# (151, 'USA', 'Salt Lake City', 'OPEN', datetime.date(2020, 11, 25), Decimal('40.746393'), Decimal('-111.900534'))
# (152, 'USA', 'Fresno', 'OPEN', datetime.date(2020, 11, 24), Decimal('36.832164'), Decimal('-119.908341'))
# (153, 'New Zealand', 'Mangaweka', 'OPEN', datetime.date(2020, 11, 24), Decimal('-39.809731'), Decimal('175.788451'))
# (154, 'USA', 'Oakland', 'OPEN', datetime.date(2020, 11, 22), Decimal('37.794153'), Decimal('-122.272578'))
# (155, 'USA', 'Austin', 'OPEN', datetime.date(2020, 11, 21), Decimal('30.4023'), Decimal('-97.7247'))
# (156, 'China', 'Hong Kong', 'OPEN', datetime.date(2020, 11, 20), Decimal('22.262361'), Decimal('114.130851'))
# (157, 'USA', 'Falls Church', 'OPEN', datetime.date(2020, 11, 20), Decimal('38.902472'), Decimal('-77.203588'))
# (158, 'USA', 'Santa Ana', 'OPEN', datetime.date(2020, 11, 20), Decimal('33.748796'), Decimal('-117.866115'))
# (159, 'USA', 'Emeryville', 'OPEN', datetime.date(2020, 11, 20), Decimal('37.840449'), Decimal('-122.293936'))
# (160, 'USA', 'Woodland', 'OPEN', datetime.date(2020, 11, 19), Decimal('38.671368'), Decimal('-121.723893'))
# (161, 'USA', 'Traver', 'OPEN', datetime.date(2020, 11, 18), Decimal('36.44881'), Decimal('-119.486404'))
# (162, 'USA', 'San Diego', 'OPEN', datetime.date(2020, 11, 18), Decimal('32.818922'), Decimal('-117.179792'))
# (163, 'USA', 'Bishop', 'OPEN', datetime.date(2020, 11, 18), Decimal('37.360397'), Decimal('-118.396963'))
# (164, 'Norway', 'Varangerbotn', 'OPEN', datetime.date(2020, 11, 18), Decimal('70.172139'), Decimal('28.555323'))
# (165, 'USA', 'Fremont', 'OPEN', datetime.date(2020, 11, 18), Decimal('37.502482'), Decimal('-121.968927'))
# (166, 'Netherlands', 'Zuidbroek', 'OPEN', datetime.date(2020, 11, 18), Decimal('53.169573'), Decimal('6.853042'))
# (167, 'USA', 'Cupertino', 'OPEN', datetime.date(2020, 11, 17), Decimal('37.324722'), Decimal('-122.03684'))
# (168, 'USA', 'Hesperia', 'OPEN', datetime.date(2020, 11, 17), Decimal('34.424864'), Decimal('-117.385861'))
# (169, 'Switzerland', 'Obfelden', 'OPEN', datetime.date(2020, 11, 14), Decimal('47.272015'), Decimal('8.437738'))
# (170, 'Switzerland', 'Affoltern am Albis', 'OPEN', datetime.date(2020, 11, 14), Decimal('47.27111'), Decimal('8.43981'))
# (171, 'USA', 'Stockton', 'OPEN', datetime.date(2020, 11, 13), Decimal('37.984978'), Decimal('-121.335924'))
# (172, 'USA', 'Firebaugh', 'OPEN', datetime.date(2020, 11, 13), Decimal('36.639287'), Decimal('-120.625451'))
# (173, 'USA', 'Palm Coast', 'OPEN', datetime.date(2020, 11, 13), Decimal('29.475857'), Decimal('-81.206442'))
# (174, 'Mexico', 'Tepatitlán de Morelos', 'OPEN', datetime.date(2020, 11, 12), Decimal('20.8102828'), Decimal('-102.7777501'))
# (175, 'France', 'Tinqueux', 'OPEN', datetime.date(2020, 11, 9), Decimal('49.252877'), Decimal('3.975955'))
# (176, 'Iceland', 'Staður', 'OPEN', datetime.date(2020, 11, 9), Decimal('65.14441'), Decimal('-21.083849'))
# (177, 'United Kingdom', 'Birmingham', 'OPEN', datetime.date(2020, 11, 9), Decimal('52.4713'), Decimal('-1.8742'))
# (178, 'USA', 'Water Mill', 'OPEN', datetime.date(2020, 11, 8), Decimal('40.912008'), Decimal('-72.352969'))
# (179, 'USA', 'Buffalo Grove', 'OPEN', datetime.date(2020, 11, 7), Decimal('42.168699'), Decimal('-87.923841'))
# (180, 'USA', 'San Jose', 'OPEN', datetime.date(2020, 11, 7), Decimal('37.417281'), Decimal('-121.956897'))
# (181, 'USA', 'Rowland Heights', 'OPEN', datetime.date(2020, 11, 7), Decimal('33.991811'), Decimal('-117.92803'))
# (182, 'Germany', 'Wörth an der Isar', 'OPEN', datetime.date(2020, 11, 6), Decimal('48.625639'), Decimal('12.320222'))
# (183, 'USA', 'Playa Vista', 'OPEN', datetime.date(2020, 11, 6), Decimal('33.977104'), Decimal('-118.417167'))
# (184, 'USA', 'Salem', 'OPEN', datetime.date(2020, 11, 5), Decimal('44.93894'), Decimal('-122.987919'))
# (185, 'USA', 'Jackson', 'OPEN', datetime.date(2020, 11, 5), Decimal('38.347998'), Decimal('-120.7766'))
# (186, 'USA', 'Hillsboro', 'OPEN', datetime.date(2020, 11, 5), Decimal('45.538579'), Decimal('-122.866166'))
# (187, 'France', 'Labouheyre', 'OPEN', datetime.date(2020, 11, 5), Decimal('44.2028103'), Decimal('-0.9268266'))
# (188, 'USA', 'Hilton Head Island', 'OPEN', datetime.date(2020, 11, 5), Decimal('32.15369'), Decimal('-80.767933'))
# (189, 'USA', 'Medford', 'OPEN', datetime.date(2020, 11, 4), Decimal('42.347992'), Decimal('-122.878882'))
# (190, 'Belgium', 'Rhisnes', 'OPEN', datetime.date(2020, 11, 2), Decimal('50.485513'), Decimal('4.7961364'))
# (191, 'USA', 'Daytona Beach', 'OPEN', datetime.date(2020, 11, 1), Decimal('29.183314'), Decimal('-81.07889'))
# (192, 'USA', 'Lacey', 'OPEN', datetime.date(2020, 10, 30), Decimal('47.0427557461906'), Decimal('-122.836407423019'))
# (193, 'USA', 'Aurora', 'OPEN', datetime.date(2020, 10, 30), Decimal('41.769119'), Decimal('-88.208105'))
# (194, 'USA', 'Hartford', 'OPEN', datetime.date(2020, 10, 30), Decimal('41.788236'), Decimal('-72.65582'))
# (195, 'Spain', 'Benavente', 'OPEN', datetime.date(2020, 10, 29), Decimal('42.0076352'), Decimal('-5.6633678'))
# (196, 'USA', 'North Charleston', 'OPEN', datetime.date(2020, 10, 29), Decimal('32.872626'), Decimal('-80.015535'))
# (197, 'China', 'Tung Chung', 'OPEN', datetime.date(2020, 10, 29), Decimal('22.290402'), Decimal('113.940136'))
# (198, 'Spain', 'Lugo', 'OPEN', datetime.date(2020, 10, 28), Decimal('43.0364661'), Decimal('-7.5690078'))
# (199, 'USA', 'Claymont', 'OPEN', datetime.date(2020, 10, 28), Decimal('39.794589561233245'), Decimal('-75.46957254409'))
# (200, 'Canada', 'Nepean', 'OPEN', datetime.date(2020, 10, 23), Decimal('45.32191'), Decimal('-75.835509'))
# (201, 'USA', 'Pittsburgh', 'OPEN', datetime.date(2020, 10, 21), Decimal('40.456432'), Decimal('-79.934125'))
# (202, 'Slovenia', 'Kozina', 'OPEN', datetime.date(2020, 10, 20), Decimal('45.607387'), Decimal('13.931518'))
# (203, 'USA', 'Palmdale', 'OPEN', datetime.date(2020, 10, 19), Decimal('34.606207'), Decimal('-118.151386'))
# (204, 'France', 'Saint-Victor', 'OPEN', datetime.date(2020, 10, 19), Decimal('46.37831'), Decimal('2.586475'))
# (205, 'USA', 'Titusville', 'OPEN', datetime.date(2020, 10, 18), Decimal('28.552782'), Decimal('-80.840594'))
# (206, 'USA', 'Lincoln', 'OPEN', datetime.date(2020, 10, 15), Decimal('38.869969'), Decimal('-121.303187'))
# (207, 'USA', 'Gettysburg', 'OPEN', datetime.date(2020, 10, 15), Decimal('39.844127'), Decimal('-77.19905'))
# (208, 'Norway', 'Vøringsfossen', 'OPEN', datetime.date(2020, 10, 14), Decimal('60.41054'), Decimal('7.325091'))
# (209, 'USA', 'Baltimore', 'OPEN', datetime.date(2020, 10, 13), Decimal('39.274972'), Decimal('-76.563528'))
# (210, 'Italy', 'Grosseto', 'OPEN', datetime.date(2020, 10, 12), Decimal('42.789258'), Decimal('11.115675'))
# (211, 'USA', 'Valdosta', 'OPEN', datetime.date(2020, 10, 11), Decimal('30.81732'), Decimal('-83.320889'))
# (212, 'USA', 'Brighton', 'OPEN', datetime.date(2020, 10, 8), Decimal('39.971722'), Decimal('-104.748972'))
# (213, 'Germany', 'Hilden', 'OPEN', datetime.date(2020, 10, 8), Decimal('51.191263'), Decimal('6.937104'))
# (214, 'USA', 'Minneapolis', 'OPEN', datetime.date(2020, 10, 7), Decimal('45.004609'), Decimal('-93.229542'))
# (215, 'France', 'Grand Font', 'OPEN', datetime.date(2020, 10, 7), Decimal('45.152092'), Decimal('0.791146'))
# (216, 'USA', 'Hawthorne', 'OPEN', datetime.date(2020, 10, 5), Decimal('33.923198'), Decimal('-118.322218'))
# (217, 'USA', 'Superior', 'OPEN', datetime.date(2020, 10, 2), Decimal('39.9548017'), Decimal('-105.1646291'))
# (218, 'USA', 'Fort Pierce', 'OPEN', datetime.date(2020, 10, 2), Decimal('27.416538'), Decimal('-80.381845'))
# (219, 'Netherlands', 'Uden', 'OPEN', datetime.date(2020, 10, 1), Decimal('51.6714'), Decimal('5.6031'))
# (220, 'USA', 'San Clemente', 'OPEN', datetime.date(2020, 10, 1), Decimal('33.463091'), Decimal('-117.60783'))
# (221, 'United Kingdom', 'Inverness', 'OPEN', datetime.date(2020, 10, 1), Decimal('57.481303'), Decimal('-4.226404'))
# (222, 'USA', 'Sacramento', 'OPEN', datetime.date(2020, 9, 30), Decimal('38.533691'), Decimal('-121.4961'))
# (223, 'United Kingdom', 'Salisbury', 'OPEN', datetime.date(2020, 9, 29), Decimal('51.1771'), Decimal('-1.7564'))
# (224, 'Netherlands', 'Leusden', 'OPEN', datetime.date(2020, 9, 29), Decimal('52.1438244'), Decimal('5.4169032'))
# (225, 'USA', 'Great Barrington', 'OPEN', datetime.date(2020, 9, 26), Decimal('42.180663'), Decimal('-73.364632'))
# (226, 'Taiwan', 'Beitou District, Taipei City', 'OPEN', datetime.date(2020, 9, 25), Decimal('25.1285'), Decimal('121.498'))
# (227, 'United Kingdom', 'Fort William', 'OPEN', datetime.date(2020, 9, 24), Decimal('56.821388'), Decimal('-5.103697'))
# (228, 'USA', 'Simi Valley', 'OPEN', datetime.date(2020, 9, 22), Decimal('34.272167'), Decimal('-118.797139'))
# (229, 'South Korea', 'Busan', 'OPEN', datetime.date(2020, 9, 19), Decimal('35.188372'), Decimal('129.110238'))
# (230, 'USA', 'Jacksonville', 'OPEN', datetime.date(2020, 9, 19), Decimal('30.307077'), Decimal('-81.847887'))
# (231, 'Switzerland', 'Bulle', 'OPEN', datetime.date(2020, 9, 19), Decimal('46.624995'), Decimal('7.037417'))
# (232, 'Canada', 'Kincardine', 'OPEN', datetime.date(2020, 9, 18), Decimal('44.172613'), Decimal('-81.615962'))
# (233, 'USA', 'Kinston', 'OPEN', datetime.date(2020, 9, 18), Decimal('35.26079'), Decimal('-77.649666'))
# (234, 'USA', 'Santa Clara', 'OPEN', datetime.date(2020, 9, 17), Decimal('37.394816'), Decimal('-121.945157'))
# (235, 'Germany', 'Eschborn', 'OPEN', datetime.date(2020, 9, 16), Decimal('50.1343207'), Decimal('8.5607616'))
# (236, 'USA', 'Las Vegas', 'OPEN', datetime.date(2020, 9, 15), Decimal('36.165908'), Decimal('-115.158343'))
# (237, 'Taiwan', 'Sanmin District, Kaohsiung City', 'OPEN', datetime.date(2020, 9, 15), Decimal('22.656359'), Decimal('120.3151366'))
# (238, 'USA', 'Chillicothe', 'OPEN', datetime.date(2020, 9, 12), Decimal('39.35835'), Decimal('-82.977277'))
# (239, 'Germany', 'Berlin', 'OPEN', datetime.date(2020, 9, 10), Decimal('52.480894'), Decimal('13.355937'))
# (240, 'USA', 'Lady Lake', 'OPEN', datetime.date(2020, 9, 9), Decimal('28.917179'), Decimal('-81.923031'))
# (241, 'USA', 'Nashville', 'OPEN', datetime.date(2020, 9, 6), Decimal('36.042377'), Decimal('-86.777844'))
# (242, 'Taiwan', 'Xizhi District, New Taipei City', 'OPEN', datetime.date(2020, 9, 6), Decimal('25.074837'), Decimal('121.6378285'))
# (243, 'USA', 'Conifer', 'OPEN', datetime.date(2020, 9, 5), Decimal('39.544083'), Decimal('-105.289972'))
# (244, 'USA', 'Rutland', 'OPEN', datetime.date(2020, 9, 5), Decimal('43.617562'), Decimal('-72.957208'))
# (245, 'USA', 'Paso Robles', 'OPEN', datetime.date(2020, 9, 4), Decimal('35.645482'), Decimal('-120.660047'))
# (246, 'USA', 'Cerritos', 'OPEN', datetime.date(2020, 9, 4), Decimal('33.8643904'), Decimal('-118.0915723'))
# (247, 'USA', 'Ozark', 'OPEN', datetime.date(2020, 9, 4), Decimal('35.5238'), Decimal('-93.8636'))
# (248, 'USA', 'Sausalito', 'OPEN', datetime.date(2020, 9, 3), Decimal('37.872835'), Decimal('-122.510499'))
# (249, 'USA', 'Ontario', 'OPEN', datetime.date(2020, 9, 3), Decimal('44.025818'), Decimal('-116.942521'))
# (250, 'Norway', 'Aksdal', 'OPEN', datetime.date(2020, 9, 3), Decimal('59.421338'), Decimal('5.443543'))
# (251, 'USA', 'Lakeland', 'OPEN', datetime.date(2020, 9, 3), Decimal('28.0979989'), Decimal('-81.9746033'))
# (252, 'Germany', 'Hermsdorf', 'OPEN', datetime.date(2020, 9, 1), Decimal('50.889767'), Decimal('11.871249'))
# (253, 'USA', 'San Jose', 'OPEN', datetime.date(2020, 8, 29), Decimal('37.300551'), Decimal('-121.825198'))
# (254, 'USA', 'Patterson', 'OPEN', datetime.date(2020, 8, 29), Decimal('37.466496'), Decimal('-121.174403'))
# (255, 'USA', 'Panama City Beach', 'OPEN', datetime.date(2020, 8, 28), Decimal('30.211432'), Decimal('-85.849367'))
# (256, 'USA', 'Minnetonka', 'OPEN', datetime.date(2020, 8, 27), Decimal('44.9698145'), Decimal('-93.4478659'))
# (257, 'United Kingdom', 'Wyboston', 'OPEN', datetime.date(2020, 8, 25), Decimal('52.2024'), Decimal('-0.2915'))
# (258, 'USA', 'Elizabeth', 'OPEN', datetime.date(2020, 8, 25), Decimal('40.662806'), Decimal('-74.173611'))
# (259, 'Portugal', 'Almancil', 'OPEN', datetime.date(2020, 8, 24), Decimal('37.097586'), Decimal('-7.9978675'))
# (260, 'China', 'Tseung Kwan O, New Territories', 'OPEN', datetime.date(2020, 8, 23), Decimal('22.296873'), Decimal('114.269887'))
# (261, 'USA', 'Ashland', 'OPEN', datetime.date(2020, 8, 21), Decimal('43.698101'), Decimal('-71.640119'))
# (262, 'Germany', 'Wismar', 'OPEN', datetime.date(2020, 8, 20), Decimal('53.878994'), Decimal('11.454682'))
# (263, 'USA', 'Brunswick', 'OPEN', datetime.date(2020, 8, 18), Decimal('31.245874'), Decimal('-81.501667'))
# (264, 'Mexico', 'Morelia', 'OPEN', datetime.date(2020, 8, 14), Decimal('19.84131'), Decimal('-101.024823'))
# (265, 'USA', 'San Francisco', 'OPEN', datetime.date(2020, 8, 14), Decimal('37.781296'), Decimal('-122.421394'))
# (266, 'France', 'Les Herbiers', 'OPEN', datetime.date(2020, 8, 11), Decimal('46.889425'), Decimal('-1.034616'))
# (267, 'USA', 'Kremmling', 'OPEN', datetime.date(2020, 8, 8), Decimal('40.059575'), Decimal('-106.387881'))
# (268, 'USA', 'Los Altos', 'OPEN', datetime.date(2020, 8, 7), Decimal('37.398894'), Decimal('-122.110682'))
# (269, 'Canada', 'Peterborough', 'OPEN', datetime.date(2020, 8, 6), Decimal('44.28343'), Decimal('-78.332347'))
# (270, 'USA', 'Washington', 'OPEN', datetime.date(2020, 8, 5), Decimal('40.1873056'), Decimal('-80.2293889'))
# (271, 'United Kingdom', 'Leeds', 'OPEN', datetime.date(2020, 8, 5), Decimal('53.784591281445174'), Decimal('-1.532506942749'))
# (272, 'United Kingdom', 'Wolverhampton', 'OPEN', datetime.date(2020, 8, 5), Decimal('52.644074'), Decimal('-2.054209'))
# (273, 'USA', 'Chula Vista', 'OPEN', datetime.date(2020, 8, 4), Decimal('32.649168'), Decimal('-116.9676'))
# (274, 'France', 'Champniers', 'OPEN', datetime.date(2020, 7, 31), Decimal('45.6944312'), Decimal('0.1788031'))
# (275, 'USA', 'Springfield', 'OPEN', datetime.date(2020, 7, 30), Decimal('40.717706'), Decimal('-74.329462'))
# (276, 'USA', 'Deptford', 'OPEN', datetime.date(2020, 7, 29), Decimal('39.833413'), Decimal('-75.097737'))
# (277, 'Spain', 'Fuentespina', 'OPEN', datetime.date(2020, 7, 29), Decimal('41.62361'), Decimal('-3.687539'))
# (278, 'Iceland', 'Reykjavik', 'OPEN', datetime.date(2020, 7, 27), Decimal('64.117675'), Decimal('-21.899378'))
# (279, 'USA', 'Katy', 'OPEN', datetime.date(2020, 7, 24), Decimal('29.774658'), Decimal('-95.821859'))
# (280, 'Netherlands', 'Middelburg', 'OPEN', datetime.date(2020, 7, 24), Decimal('51.4802623'), Decimal('3.6364364'))
# (281, 'Italy', 'Forlì', 'OPEN', datetime.date(2020, 7, 23), Decimal('44.242877'), Decimal('12.081828'))
# (282, 'Denmark', 'Ikast', 'OPEN', datetime.date(2020, 7, 22), Decimal('56.121583'), Decimal('9.172972'))
# (283, 'USA', 'Elk Grove', 'OPEN', datetime.date(2020, 7, 21), Decimal('38.409389'), Decimal('-121.391028'))
# (284, 'Canada', 'Perth', 'OPEN', datetime.date(2020, 7, 20), Decimal('44.908247'), Decimal('-76.265416'))
# (285, 'USA', 'Santa Cruz', 'OPEN', datetime.date(2020, 7, 18), Decimal('36.978635'), Decimal('-122.013968'))
# (286, 'Netherlands', 'Akersloot', 'OPEN', datetime.date(2020, 7, 16), Decimal('52.547626'), Decimal('4.722645'))
# (287, 'Norway', 'Svolvær', 'OPEN', datetime.date(2020, 7, 16), Decimal('68.233259'), Decimal('14.560533'))
# (288, 'USA', 'Vienna', 'OPEN', datetime.date(2020, 7, 16), Decimal('38.895195'), Decimal('-77.273938'))
# (289, 'Mexico', 'Villa Hidalgo', 'OPEN', datetime.date(2020, 7, 15), Decimal('22.51993'), Decimal('-100.664291'))
# (290, 'USA', 'South Riding', 'OPEN', datetime.date(2020, 7, 15), Decimal('38.9137222'), Decimal('-77.4869722'))
# (291, 'USA', 'Modesto', 'OPEN', datetime.date(2020, 7, 13), Decimal('37.694343'), Decimal('-121.064215'))
# (292, 'Netherlands', 'Apeldoorn', 'OPEN', datetime.date(2020, 7, 9), Decimal('52.205041'), Decimal('6.016368'))
# (293, 'USA', 'Bothell', 'OPEN', datetime.date(2020, 7, 9), Decimal('47.767606'), Decimal('-122.191712'))
# (294, 'USA', 'Lake Placid', 'OPEN', datetime.date(2020, 7, 8), Decimal('44.294797'), Decimal('-74.010526'))
# (295, 'USA', 'Heyburn', 'OPEN', datetime.date(2020, 7, 8), Decimal('42.56159'), Decimal('-113.790261'))
# (296, 'Taiwan', 'West Central District, Tainan City', 'OPEN', datetime.date(2020, 7, 4), Decimal('22.990136'), Decimal('120.200944'))
# (297, 'Japan', 'Nayoga-Shi', 'OPEN', datetime.date(2020, 7, 3), Decimal('35.160779'), Decimal('136.984593'))
# (298, 'USA', 'El Cerrito', 'OPEN', datetime.date(2020, 7, 3), Decimal('37.898575'), Decimal('-122.30073'))
# (299, 'Netherlands', 'Rijswijk', 'OPEN', datetime.date(2020, 7, 3), Decimal('52.048281'), Decimal('4.349134'))
# (300, 'USA', 'Evansville', 'OPEN', datetime.date(2020, 7, 2), Decimal('42.846691'), Decimal('-106.214485'))
# (301, 'USA', 'Gallatin Gateway', 'OPEN', datetime.date(2020, 7, 2), Decimal('45.2606761'), Decimal('-111.3062058'))
# (302, 'USA', 'Beaumont', 'OPEN', datetime.date(2020, 7, 2), Decimal('33.922543'), Decimal('-116.949167'))
# (303, 'USA', 'Chicago', 'OPEN', datetime.date(2020, 7, 2), Decimal('41.99870660096533'), Decimal('-87.888457775115'))
# (304, 'USA', 'Louisville', 'OPEN', datetime.date(2020, 7, 1), Decimal('38.299'), Decimal('-85.556056'))
# (305, 'Norway', 'Stathelle', 'OPEN', datetime.date(2020, 6, 30), Decimal('58.971256'), Decimal('9.512438'))
# (306, 'United Kingdom', 'Colchester', 'OPEN', datetime.date(2020, 6, 30), Decimal('51.8807'), Decimal('0.7889'))
# (307, 'Taiwan', 'Da’an District, Taipei City', 'OPEN', datetime.date(2020, 6, 29), Decimal('25.020459'), Decimal('121.543099'))
# (308, 'USA', 'Great Falls', 'OPEN', datetime.date(2020, 6, 27), Decimal('47.48295'), Decimal('-111.337681'))
# (309, 'USA', 'Reston', 'OPEN', datetime.date(2020, 6, 26), Decimal('38.949021'), Decimal('-77.339711'))
# (310, 'USA', 'Helena', 'OPEN', datetime.date(2020, 6, 26), Decimal('46.618173'), Decimal('-112.007628'))
# (311, 'USA', 'White Marsh', 'OPEN', datetime.date(2020, 6, 26), Decimal('39.373985'), Decimal('-76.443133'))
# (312, 'USA', 'Farmville', 'OPEN', datetime.date(2020, 6, 25), Decimal('37.271854'), Decimal('-78.401442'))
# (313, 'USA', 'Bethel', 'OPEN', datetime.date(2020, 6, 24), Decimal('44.424871'), Decimal('-70.796608'))
# (314, 'USA', 'Freehold', 'OPEN', datetime.date(2020, 6, 24), Decimal('40.238319'), Decimal('-74.228021'))
# (315, 'United Kingdom', 'Wolverhampton', 'OPEN', datetime.date(2020, 6, 23), Decimal('52.644063'), Decimal('-2.058389'))
# (316, 'USA', 'Bismarck', 'OPEN', datetime.date(2020, 6, 20), Decimal('46.832972'), Decimal('-100.807222'))
# (317, 'USA', 'Flossmoor', 'OPEN', datetime.date(2020, 6, 19), Decimal('41.529391'), Decimal('-87.709287'))
# (318, 'USA', 'Glendive', 'OPEN', datetime.date(2020, 6, 19), Decimal('47.127042'), Decimal('-104.694456'))
# (319, 'USA', 'Oakland', 'OPEN', datetime.date(2020, 6, 18), Decimal('37.746403'), Decimal('-122.195614'))
# (320, 'USA', 'Miles City', 'OPEN', datetime.date(2020, 6, 18), Decimal('46.390475'), Decimal('-105.823359'))
# (321, 'USA', 'Dickinson', 'OPEN', datetime.date(2020, 6, 17), Decimal('46.901222'), Decimal('-102.790822'))
# (322, 'USA', 'Jamestown', 'OPEN', datetime.date(2020, 6, 17), Decimal('46.88465891260407'), Decimal('-98.719555735588'))
# (323, 'USA', 'Buena Park', 'OPEN', datetime.date(2020, 6, 17), Decimal('33.86044'), Decimal('-117.996347'))
# (324, 'USA', 'Englewood', 'OPEN', datetime.date(2020, 6, 14), Decimal('39.567218'), Decimal('-104.877928'))
# (325, 'USA', 'Hardeeville', 'OPEN', datetime.date(2020, 6, 13), Decimal('32.27012485'), Decimal('-81.08084499'))
# (326, 'USA', 'Miami', 'OPEN', datetime.date(2020, 6, 11), Decimal('25.693198'), Decimal('-80.304898'))
# (327, 'USA', 'Mackinaw City', 'OPEN', datetime.date(2020, 6, 10), Decimal('45.77225'), Decimal('-84.7265'))
# (328, 'USA', 'Hermosa Beach', 'OPEN', datetime.date(2020, 6, 10), Decimal('33.864955'), Decimal('-118.394819'))
# (329, 'USA', 'Pismo Beach', 'OPEN', datetime.date(2020, 6, 8), Decimal('35.136408'), Decimal('-120.628662'))
# (330, 'USA', 'Richmond', 'OPEN', datetime.date(2020, 5, 30), Decimal('37.898736'), Decimal('-122.308672'))
# (331, 'USA', 'Kelso', 'OPEN', datetime.date(2020, 5, 29), Decimal('46.143403'), Decimal('-122.899225'))
# (332, 'USA', 'Fargo', 'OPEN', datetime.date(2020, 5, 29), Decimal('46.843601'), Decimal('-96.882492'))
# (333, 'USA', 'Easton', 'OPEN', datetime.date(2020, 5, 28), Decimal('38.759257'), Decimal('-76.061405'))
# (334, 'USA', 'Emporia', 'OPEN', datetime.date(2020, 5, 28), Decimal('38.414266'), Decimal('-96.216714'))
# (335, 'USA', 'St. Louis Park', 'OPEN', datetime.date(2020, 5, 27), Decimal('44.935964'), Decimal('-93.347857'))
# (336, 'USA', 'Hyannis', 'OPEN', datetime.date(2020, 5, 20), Decimal('41.676619'), Decimal('-70.307049'))
# (337, 'USA', 'Bensalem', 'OPEN', datetime.date(2020, 5, 19), Decimal('40.124944'), Decimal('-74.963908'))
# (338, 'USA', 'Willow Beach', 'OPEN', datetime.date(2020, 5, 13), Decimal('35.7'), Decimal('-114.476782'))
# (339, 'USA', 'Manteca', 'OPEN', datetime.date(2020, 5, 9), Decimal('37.795975'), Decimal('-121.19771'))
# (340, 'USA', 'Goleta', 'OPEN', datetime.date(2020, 5, 6), Decimal('34.427015'), Decimal('-119.871768'))
# (341, 'USA', 'Gilman', 'OPEN', datetime.date(2020, 5, 6), Decimal('40.752202'), Decimal('-87.996464'))
# (342, 'USA', 'Schertz', 'OPEN', datetime.date(2020, 5, 2), Decimal('29.598455'), Decimal('-98.276067'))
# (343, 'Poland', 'Nowa Wieś', 'OPEN', datetime.date(2020, 4, 25), Decimal('50.089246'), Decimal('22.045561'))
# (344, 'USA', 'Deltona', 'OPEN', datetime.date(2020, 4, 25), Decimal('28.9498974'), Decimal('-81.2508045'))
# (345, 'Norway', 'Mosjøen', 'OPEN', datetime.date(2020, 4, 24), Decimal('65.841737'), Decimal('13.187839'))
# (346, 'USA', 'Canaan', 'OPEN', datetime.date(2020, 4, 17), Decimal('42.024331'), Decimal('-73.322684'))
# (347, 'USA', 'Revere', 'OPEN', datetime.date(2020, 4, 11), Decimal('42.398547'), Decimal('-71.00021'))
# (348, 'USA', 'Richmond', 'OPEN', datetime.date(2020, 4, 8), Decimal('39.868255'), Decimal('-84.886326'))
# (349, 'USA', 'Fort Lauderdale', 'OPEN', datetime.date(2020, 4, 6), Decimal('26.120885'), Decimal('-80.177098'))
# (350, 'Australia', 'Gympie', 'OPEN', datetime.date(2020, 4, 6), Decimal('-26.188285'), Decimal('152.661475'))
# (351, 'Canada', 'Niagara Falls', 'OPEN', datetime.date(2020, 4, 3), Decimal('43.116772'), Decimal('-79.124184'))
# (352, 'Taiwan', 'Xiulin Township', 'OPEN', datetime.date(2020, 3, 31), Decimal('24.3013591'), Decimal('121.7513107'))
# (353, 'USA', 'Lakewood', 'OPEN', datetime.date(2020, 3, 31), Decimal('39.733697'), Decimal('-105.154154'))
# (354, 'Canada', 'Kitchener', 'OPEN', datetime.date(2020, 3, 31), Decimal('43.461295'), Decimal('-80.472305'))
# (355, 'China', 'Wuhou District, Chengdu', 'OPEN', datetime.date(2020, 3, 31), Decimal('30.6258049'), Decimal('103.988644'))
# (356, 'China', 'Xindu District 3', 'OPEN', datetime.date(2020, 3, 31), Decimal('30.8138103'), Decimal('104.1591601'))
# (357, 'Australia', 'Camberwell', 'OPEN', datetime.date(2020, 3, 31), Decimal('-37.828879'), Decimal('145.056387'))
# (358, 'Japan', 'Osaka', 'OPEN', datetime.date(2020, 3, 31), Decimal('34.757218'), Decimal('135.461799'))
# (359, 'USA', 'Forks', 'OPEN', datetime.date(2020, 3, 30), Decimal('47.942522'), Decimal('-124.384748'))
# (360, 'Poland', 'Katowice', 'OPEN', datetime.date(2020, 3, 30), Decimal('50.220179'), Decimal('18.990308'))
# (361, 'China', 'Minhang District', 'OPEN', datetime.date(2020, 3, 29), Decimal('31.188757751934183'), Decimal('121.40182256698'))
# (362, 'USA', 'Novato', 'OPEN', datetime.date(2020, 3, 28), Decimal('38.089447'), Decimal('-122.551755'))
# (363, 'USA', 'Emeryville', 'OPEN', datetime.date(2020, 3, 28), Decimal('37.837506'), Decimal('-122.295407'))
# (364, 'USA', 'Mission Viejo', 'OPEN', datetime.date(2020, 3, 25), Decimal('33.557279'), Decimal('-117.668035'))
# (365, 'USA', 'San Antonio', 'OPEN', datetime.date(2020, 3, 25), Decimal('29.665289'), Decimal('-98.633387'))
# (366, 'USA', 'Vancouver', 'OPEN', datetime.date(2020, 3, 24), Decimal('45.659872'), Decimal('-122.582467'))
# (367, 'Canada', 'London', 'OPEN', datetime.date(2020, 3, 24), Decimal('42.917358'), Decimal('-81.208505'))
# (368, 'USA', 'Tacna', 'OPEN', datetime.date(2020, 3, 24), Decimal('32.690622'), Decimal('-113.953578'))
# (369, 'USA', 'Michigan City', 'OPEN', datetime.date(2020, 3, 24), Decimal('41.673833'), Decimal('-86.891234'))
# (370, 'United Kingdom', 'Bristol', 'OPEN', datetime.date(2020, 3, 23), Decimal('51.522889'), Decimal('-2.609222'))
# (371, 'USA', 'Fishkill', 'OPEN', datetime.date(2020, 3, 22), Decimal('41.52727858284335'), Decimal('-73.893152475357'))
# (372, 'USA', 'Tumwater', 'OPEN', datetime.date(2020, 3, 21), Decimal('46.952944'), Decimal('-122.935111'))
# (373, 'USA', 'Northbrook', 'OPEN', datetime.date(2020, 3, 18), Decimal('42.107745'), Decimal('-87.802496'))
# (374, 'Canada', 'Abbotsford', 'OPEN', datetime.date(2020, 3, 16), Decimal('49.0580075'), Decimal('-122.378125'))
# (375, 'USA', 'Vero Beach', 'OPEN', datetime.date(2020, 3, 16), Decimal('27.6400894'), Decimal('-80.5135068'))
# (376, 'USA', 'Lancaster', 'OPEN', datetime.date(2020, 3, 14), Decimal('40.052622'), Decimal('-76.254776'))
# (377, 'Serbia', 'Aleksinac', 'OPEN', datetime.date(2020, 3, 13), Decimal('43.528789'), Decimal('21.709381'))
# (378, 'Serbia', 'Beograd', 'OPEN', datetime.date(2020, 3, 13), Decimal('44.711568'), Decimal('20.562039'))
# (379, 'Norway', 'Lierskogen', 'OPEN', datetime.date(2020, 3, 12), Decimal('59.808633'), Decimal('10.299023'))
# (380, 'Bulgaria', 'Plovdiv', 'OPEN', datetime.date(2020, 3, 11), Decimal('42.144521'), Decimal('24.768837'))
# (381, 'USA', 'New London', 'OPEN', datetime.date(2020, 3, 7), Decimal('41.370726'), Decimal('-72.119398'))
# (382, 'USA', 'Washington', 'OPEN', datetime.date(2020, 3, 6), Decimal('38.91655'), Decimal('-77.066175'))
# (383, 'Australia', 'Macquarie Park', 'OPEN', datetime.date(2020, 3, 5), Decimal('-33.777217'), Decimal('151.12088'))
# (384, 'USA', 'Chestertown', 'OPEN', datetime.date(2020, 3, 5), Decimal('43.665802'), Decimal('-73.784266'))
# (385, 'Australia', 'South Toowoomba', 'OPEN', datetime.date(2020, 3, 4), Decimal('-27.577891'), Decimal('151.946812'))
# (386, 'China', 'Beijing', 'OPEN', datetime.date(2020, 2, 29), Decimal('39.982954'), Decimal('116.452092'))
# (387, 'USA', 'Thornton', 'OPEN', datetime.date(2020, 2, 28), Decimal('39.914711'), Decimal('-104.986758'))
# (388, 'USA', 'Copiague', 'OPEN', datetime.date(2020, 2, 27), Decimal('40.688444'), Decimal('-73.4055'))
# (389, 'USA', 'Deerfield Beach', 'OPEN', datetime.date(2020, 2, 25), Decimal('26.317736'), Decimal('-80.119643'))
# (390, 'USA', 'Williamsport', 'OPEN', datetime.date(2020, 2, 25), Decimal('41.2328'), Decimal('-77.019865'))
# (391, 'France', 'Buchelay', 'OPEN', datetime.date(2020, 2, 25), Decimal('48.990167'), Decimal('1.671528'))
# (392, 'USA', 'Bloomington', 'OPEN', datetime.date(2020, 2, 25), Decimal('39.166222'), Decimal('-86.579116'))
# (393, 'USA', 'Riverside', 'OPEN', datetime.date(2020, 2, 25), Decimal('33.939957'), Decimal('-117.282508'))
# (394, 'USA', 'Kokomo', 'OPEN', datetime.date(2020, 2, 25), Decimal('40.475169'), Decimal('-86.101306'))
# (395, 'USA', 'Lowell', 'OPEN', datetime.date(2020, 2, 21), Decimal('36.255329'), Decimal('-94.152637'))
# (396, 'USA', 'Maple Shade', 'OPEN', datetime.date(2020, 2, 21), Decimal('39.937134'), Decimal('-74.970511'))
# (397, 'Norway', 'Gol', 'OPEN', datetime.date(2020, 2, 21), Decimal('60.697433'), Decimal('8.953477'))
# (398, 'USA', 'Ashburn', 'OPEN', datetime.date(2020, 2, 20), Decimal('39.008466'), Decimal('-77.504972'))
# (399, 'USA', 'Clearwater', 'OPEN', datetime.date(2020, 2, 18), Decimal('28.013295'), Decimal('-82.736244'))
# (400, 'USA', 'Roseville', 'OPEN', datetime.date(2020, 2, 18), Decimal('38.767949'), Decimal('-121.263356'))
# (401, 'Japan', 'Hiroshima', 'OPEN', datetime.date(2020, 2, 15), Decimal('34.372844'), Decimal('132.404382'))
# (402, 'Belgium', 'Remouchamps', 'OPEN', datetime.date(2020, 2, 15), Decimal('50.484271'), Decimal('5.70141'))
# (403, 'USA', 'Ochopee', 'OPEN', datetime.date(2020, 2, 14), Decimal('26.173437'), Decimal('-80.855101'))
# (404, 'USA', 'South San Francisco', 'OPEN', datetime.date(2020, 2, 14), Decimal('37.655243'), Decimal('-122.401321'))
# (405, 'USA', 'Alexandria', 'OPEN', datetime.date(2020, 2, 14), Decimal('45.850405'), Decimal('-95.388969'))
# (406, 'USA', 'Lafayette', 'OPEN', datetime.date(2020, 2, 13), Decimal('30.265264'), Decimal('-91.994232'))
# (407, 'Sweden', 'Storlien', 'OPEN', datetime.date(2020, 2, 13), Decimal('63.31038'), Decimal('12.109508'))
# (408, 'Sweden', 'Borlänge', 'OPEN', datetime.date(2020, 2, 11), Decimal('60.478749'), Decimal('15.438795'))
# (409, 'USA', 'Meriden', 'OPEN', datetime.date(2020, 2, 9), Decimal('41.527018'), Decimal('-72.773982'))
# (410, 'USA', 'Buffalo', 'OPEN', datetime.date(2020, 2, 8), Decimal('42.90741'), Decimal('-78.762239'))
# (411, 'USA', 'Madison', 'OPEN', datetime.date(2020, 2, 7), Decimal('38.34664'), Decimal('-78.286103'))
# (412, 'USA', 'Oneonta', 'OPEN', datetime.date(2020, 2, 7), Decimal('42.447575'), Decimal('-75.048622'))
# (413, 'USA', 'West Ocean City', 'OPEN', datetime.date(2020, 2, 7), Decimal('38.335586'), Decimal('-75.104509'))
# (414, 'USA', 'Grove City', 'OPEN', datetime.date(2020, 2, 7), Decimal('41.143778'), Decimal('-80.157055'))
# (415, 'USA', 'Idaho Springs', 'OPEN', datetime.date(2020, 2, 6), Decimal('39.741549'), Decimal('-105.518358'))
# (416, 'USA', 'Lynchburg', 'OPEN', datetime.date(2020, 2, 6), Decimal('37.32486'), Decimal('-79.190523'))
# (417, 'Canada', 'Chicoutimi', 'OPEN', datetime.date(2020, 2, 1), Decimal('48.401913'), Decimal('-71.062556'))
# (418, 'USA', 'Madison', 'OPEN', datetime.date(2020, 1, 30), Decimal('41.2900852'), Decimal('-72.5803292'))
# (419, 'USA', 'Madison', 'OPEN', datetime.date(2020, 1, 30), Decimal('41.2915926'), Decimal('-72.5790793'))
# (420, 'USA', 'Scotts Valley', 'OPEN', datetime.date(2020, 1, 30), Decimal('37.047608'), Decimal('-122.027743'))
# (421, 'USA', 'Miami', 'OPEN', datetime.date(2020, 1, 30), Decimal('25.7485018'), Decimal('-80.3084064'))
# (422, 'USA', 'Marianna', 'OPEN', datetime.date(2020, 1, 29), Decimal('30.716016'), Decimal('-85.184269'))
# (423, 'USA', 'North Bethesda', 'OPEN', datetime.date(2020, 1, 28), Decimal('39.050339'), Decimal('-77.11657'))
# (424, 'USA', 'Swartz Creek', 'OPEN', datetime.date(2020, 1, 28), Decimal('42.96744'), Decimal('-83.828794'))
# (425, 'USA', 'Flushing', 'OPEN', datetime.date(2020, 1, 28), Decimal('40.760821'), Decimal('-73.829676'))
# (426, 'Canada', 'Richmond', 'OPEN', datetime.date(2020, 1, 28), Decimal('49.170013'), Decimal('-123.138776'))
# (427, 'USA', 'New York', 'OPEN', datetime.date(2020, 1, 28), Decimal('40.714062'), Decimal('-74.015837'))
# (428, 'Taiwan', 'Zhubei City', 'OPEN', datetime.date(2020, 1, 27), Decimal('24.807265'), Decimal('121.036114'))
# (429, 'Germany', 'Pfaffenhofen an der Ilm', 'OPEN', datetime.date(2020, 1, 25), Decimal('48.518159'), Decimal('11.562124'))
# (430, 'USA', 'Rockville', 'OPEN', datetime.date(2020, 1, 25), Decimal('39.085997'), Decimal('-77.149696'))
# (431, 'Germany', 'Rauenberg', 'OPEN', datetime.date(2020, 1, 17), Decimal('49.273806'), Decimal('8.695444'))
# (432, 'Poland', 'Warsaw', 'OPEN', datetime.date(2020, 1, 16), Decimal('52.207827'), Decimal('21.029574'))
# (433, 'USA', 'Wareham', 'OPEN', datetime.date(2020, 1, 15), Decimal('41.775093'), Decimal('-70.744321'))
# (434, 'Poland', 'Radom', 'OPEN', datetime.date(2020, 1, 15), Decimal('51.379569'), Decimal('21.125477'))
# (435, 'USA', 'Kissimmee', 'OPEN', datetime.date(2020, 1, 13), Decimal('28.34551'), Decimal('-81.604567'))
# (436, 'USA', 'Chestnut Hill', 'OPEN', datetime.date(2020, 1, 10), Decimal('42.322031'), Decimal('-71.172395'))
# (437, 'USA', 'Alpharetta', 'OPEN', datetime.date(2020, 1, 8), Decimal('34.071582'), Decimal('-84.275404'))
# (438, 'USA', 'Moses Lake', 'OPEN', datetime.date(2020, 1, 3), Decimal('47.103505'), Decimal('-119.310203'))
# (439, 'USA', 'Skowhegan', 'OPEN', datetime.date(2020, 1, 1), Decimal('44.780304'), Decimal('-69.727027'))
# (440, 'South Korea', 'Seoul', 'OPEN', datetime.date(2019, 12, 31), Decimal('37.499873'), Decimal('127.032354'))
# ...
# (2051, 'China', 'Hangzhou', 'OPEN', datetime.date(2014, 7, 26), Decimal('30.3131265'), Decimal('120.1651448'))
# (2052, 'China', 'Shenzhen', 'OPEN', datetime.date(2014, 7, 26), Decimal('22.6189'), Decimal('114.05482'))
# (2053, 'Slovenia', 'Ljubljana', 'OPEN', datetime.date(2014, 7, 26), Decimal('46.0520565'), Decimal('14.45315'))
# (2054, 'USA', 'Billings', 'OPEN', datetime.date(2014, 7, 23), Decimal('45.733716'), Decimal('-108.604573'))
# (2055, 'China', 'Hong Kong', 'OPEN', datetime.date(2014, 7, 23), Decimal('22.274495'), Decimal('114.171429'))
# (2056, 'China', 'Hong Kong', 'OPEN', datetime.date(2014, 7, 22), Decimal('22.306989'), Decimal('114.212648'))
# (2057, 'Sweden', 'Falkenberg', 'OPEN', datetime.date(2014, 7, 18), Decimal('56.93167'), Decimal('12.51805'))
# (2058, 'Germany', 'Rhüden', 'OPEN', datetime.date(2014, 7, 17), Decimal('51.947228'), Decimal('10.140842'))
# (2059, 'Canada', 'Squamish', 'OPEN', datetime.date(2014, 7, 12), Decimal('49.736901'), Decimal('-123.134573'))
# (2060, 'China', 'Beijing', 'OPEN', datetime.date(2014, 7, 12), Decimal('39.799729'), Decimal('116.518017'))
# (2061, 'Germany', 'Kamen', 'OPEN', datetime.date(2014, 7, 12), Decimal('51.5701759'), Decimal('7.6751678'))
# (2062, 'France', 'Sancé', 'OPEN', datetime.date(2014, 7, 11), Decimal('46.346553'), Decimal('4.850173'))
# (2063, 'France', 'Nimes', 'OPEN', datetime.date(2014, 7, 11), Decimal('43.816537'), Decimal('4.345114'))
# (2064, 'USA', 'Wickenburg', 'OPEN', datetime.date(2014, 7, 11), Decimal('33.9702333'), Decimal('-112.73165'))
# (2065, 'USA', 'Tifton', 'OPEN', datetime.date(2014, 7, 10), Decimal('31.448847'), Decimal('-83.53221'))
# (2066, 'Sweden', 'Uddevalla', 'OPEN', datetime.date(2014, 7, 9), Decimal('58.3516862'), Decimal('11.8116943'))
# (2067, 'Sweden', 'Arboga', 'OPEN', datetime.date(2014, 7, 6), Decimal('59.426307'), Decimal('15.827684'))
# (2068, 'Sweden', 'Karlstad', 'OPEN', datetime.date(2014, 7, 6), Decimal('59.381535'), Decimal('13.467609'))
# (2069, 'Norway', 'Sandane', 'OPEN', datetime.date(2014, 7, 6), Decimal('61.7780226'), Decimal('6.2131884'))
# (2070, 'Germany', 'Emsbüren', 'OPEN', datetime.date(2014, 7, 4), Decimal('52.359241'), Decimal('7.264215'))
# (2071, 'USA', 'Salina', 'OPEN', datetime.date(2014, 7, 4), Decimal('38.877342'), Decimal('-97.618699'))
# (2072, 'France', 'Appoigny', 'OPEN', datetime.date(2014, 7, 4), Decimal('47.85183'), Decimal('3.542802'))
# (2073, 'Netherlands', 'Tilburg', 'OPEN', datetime.date(2014, 7, 3), Decimal('51.606331'), Decimal('5.005621'))
# (2074, 'Norway', 'Rolvsøy', 'OPEN', datetime.date(2014, 7, 3), Decimal('59.324292'), Decimal('10.954448'))
# (2075, 'Denmark', 'Hjørring', 'OPEN', datetime.date(2014, 7, 3), Decimal('57.455791'), Decimal('10.04227'))
# (2076, 'Norway', 'Vinje', 'OPEN', datetime.date(2014, 6, 27), Decimal('59.5701306'), Decimal('7.992551'))
# (2077, 'USA', 'Limon', 'OPEN', datetime.date(2014, 6, 21), Decimal('39.2688421'), Decimal('-103.708604'))
# (2078, 'Germany', 'Regensburg', 'OPEN', datetime.date(2014, 6, 18), Decimal('48.994967'), Decimal('12.150416'))
# (2079, 'Germany', 'Staufenberg', 'OPEN', datetime.date(2014, 6, 14), Decimal('51.370219'), Decimal('9.633905'))
# (2080, 'USA', 'Goodland', 'OPEN', datetime.date(2014, 6, 13), Decimal('39.326253'), Decimal('-101.725171'))
# (2081, 'Germany', 'Erbshausen', 'OPEN', datetime.date(2014, 6, 13), Decimal('49.912046'), Decimal('10.001735'))
# (2082, 'USA', 'Hays', 'OPEN', datetime.date(2014, 6, 12), Decimal('38.900543'), Decimal('-99.319142'))
# (2083, 'USA', 'Nephi', 'OPEN', datetime.date(2014, 6, 11), Decimal('39.6783968'), Decimal('-111.8407035'))
# (2084, 'Denmark', 'Middelfart', 'OPEN', datetime.date(2014, 5, 30), Decimal('55.510639'), Decimal('9.764306'))
# (2085, 'Denmark', 'Randers', 'OPEN', datetime.date(2014, 5, 30), Decimal('56.433685'), Decimal('10.055412'))
# (2086, 'China', 'Beijing', 'OPEN', datetime.date(2014, 5, 19), Decimal('39.977989'), Decimal('116.481445'))
# (2087, 'USA', 'Ritzville', 'OPEN', datetime.date(2014, 5, 18), Decimal('47.116294'), Decimal('-118.368328'))
# (2088, 'USA', 'Gila Bend', 'OPEN', datetime.date(2014, 5, 17), Decimal('32.943969'), Decimal('-112.733506'))
# (2089, 'Germany', 'Münchberg', 'OPEN', datetime.date(2014, 5, 12), Decimal('50.202872'), Decimal('11.776552'))
# (2090, 'USA', 'Macon', 'OPEN', datetime.date(2014, 5, 8), Decimal('32.8334275'), Decimal('-83.6255567'))
# (2091, 'USA', 'Triadelphia', 'OPEN', datetime.date(2014, 5, 7), Decimal('40.060757'), Decimal('-80.602874'))
# (2092, 'USA', 'San Juan Capistrano', 'OPEN', datetime.date(2014, 5, 6), Decimal('33.498458'), Decimal('-117.6632'))
# (2093, 'USA', 'Woodbridge', 'OPEN', datetime.date(2014, 5, 2), Decimal('38.64082'), Decimal('-77.29633'))
# (2094, 'USA', 'Albany', 'OPEN', datetime.date(2014, 4, 30), Decimal('42.710356'), Decimal('-73.819109'))
# (2095, 'Austria', 'Vienna', 'OPEN', datetime.date(2014, 4, 30), Decimal('48.1574455'), Decimal('16.3345536'))
# (2096, 'Germany', 'Hohenwarsleben', 'OPEN', datetime.date(2014, 4, 30), Decimal('52.174057'), Decimal('11.494488'))
# (2097, 'USA', 'Roseville', 'OPEN', datetime.date(2014, 4, 29), Decimal('38.771208'), Decimal('-121.266149'))
# (2098, 'China', 'Shanghai', 'OPEN', datetime.date(2014, 4, 23), Decimal('31.27969'), Decimal('121.16766'))
# (2099, 'USA', 'Hamilton', 'OPEN', datetime.date(2014, 4, 22), Decimal('40.195539'), Decimal('-74.641375'))
# (2100, 'USA', 'Beaver', 'OPEN', datetime.date(2014, 4, 14), Decimal('38.249149'), Decimal('-112.652524'))
# (2101, 'USA', 'Cranberry Township', 'OPEN', datetime.date(2014, 4, 4), Decimal('40.683982'), Decimal('-80.10839'))
# (2102, 'USA', 'Richfield', 'OPEN', datetime.date(2014, 4, 4), Decimal('38.787942'), Decimal('-112.085316'))
# (2103, 'USA', 'Buckeye', 'OPEN', datetime.date(2014, 3, 20), Decimal('33.443011'), Decimal('-112.556876'))
# (2104, 'USA', 'Green River', 'OPEN', datetime.date(2014, 3, 17), Decimal('38.993577'), Decimal('-110.140513'))
# (2105, 'USA', 'Plymouth', 'OPEN', datetime.date(2014, 3, 12), Decimal('35.850587'), Decimal('-76.756116'))
# (2106, 'USA', 'Las Vegas', 'OPEN', datetime.date(2014, 2, 19), Decimal('36.165906'), Decimal('-115.138655'))
# (2107, 'USA', 'Pleasant Prairie', 'OPEN', datetime.date(2014, 2, 13), Decimal('42.518715'), Decimal('-87.950428'))
# (2108, 'USA', 'Greenwich', 'OPEN', datetime.date(2014, 2, 12), Decimal('41.041538'), Decimal('-73.671661'))
# (2109, 'USA', 'Greenwich', 'OPEN', datetime.date(2014, 2, 12), Decimal('41.040555'), Decimal('-73.673445'))
# (2110, 'USA', 'Yuma', 'OPEN', datetime.date(2014, 2, 4), Decimal('32.726686'), Decimal('-114.619093'))
# (2111, 'USA', 'Eau Claire', 'OPEN', datetime.date(2014, 1, 30), Decimal('44.77083'), Decimal('-91.43711'))
# (2112, 'USA', 'Hagerstown', 'OPEN', datetime.date(2014, 1, 23), Decimal('39.605859'), Decimal('-77.733324'))
# (2113, 'USA', 'Moab', 'OPEN', datetime.date(2014, 1, 22), Decimal('38.573122'), Decimal('-109.552368'))
# (2114, 'USA', 'Kingman', 'OPEN', datetime.date(2014, 1, 22), Decimal('35.191331'), Decimal('-114.065592'))
# (2115, 'USA', 'Cheyenne', 'OPEN', datetime.date(2014, 1, 20), Decimal('41.161085'), Decimal('-104.804955'))
# (2116, 'USA', 'Lumberton', 'OPEN', datetime.date(2014, 1, 17), Decimal('34.667629'), Decimal('-79.002343'))
# (2117, 'USA', 'Holbrook', 'OPEN', datetime.date(2014, 1, 15), Decimal('34.922962'), Decimal('-110.145558'))
# (2118, 'USA', 'Savannah', 'OPEN', datetime.date(2014, 1, 15), Decimal('32.135507'), Decimal('-81.212767'))
# (2119, 'USA', 'Albert Lea', 'OPEN', datetime.date(2014, 1, 15), Decimal('43.68606'), Decimal('-93.357721'))
# (2120, 'USA', 'Macedonia', 'OPEN', datetime.date(2014, 1, 15), Decimal('41.313663'), Decimal('-81.517018'))
# (2121, 'USA', 'Maumee', 'OPEN', datetime.date(2014, 1, 13), Decimal('41.57835'), Decimal('-83.66465'))
# (2122, 'USA', 'Blanding', 'OPEN', datetime.date(2014, 1, 13), Decimal('37.6255534'), Decimal('-109.47384199999999'))
# (2123, 'USA', 'Madison', 'OPEN', datetime.date(2014, 1, 13), Decimal('43.12669'), Decimal('-89.306896'))
# (2124, 'USA', 'Grand Junction', 'OPEN', datetime.date(2014, 1, 10), Decimal('39.090758'), Decimal('-108.604325'))
# (2125, 'USA', 'Farmington', 'OPEN', datetime.date(2014, 1, 10), Decimal('36.766371'), Decimal('-108.144047'))
# (2126, 'USA', 'Somerset', 'OPEN', datetime.date(2014, 1, 10), Decimal('40.017383'), Decimal('-79.077117'))
# (2127, 'USA', 'Flagstaff', 'OPEN', datetime.date(2014, 1, 10), Decimal('35.174272'), Decimal('-111.66328'))
# (2128, 'USA', 'Gallup', 'OPEN', datetime.date(2014, 1, 7), Decimal('35.505278'), Decimal('-108.828094'))
# (2129, 'USA', 'East Greenwich', 'OPEN', datetime.date(2014, 1, 6), Decimal('41.660517'), Decimal('-71.497242'))
# (2130, 'USA', 'Onalaska', 'OPEN', datetime.date(2014, 1, 5), Decimal('43.879042'), Decimal('-91.188428'))
# (2131, 'USA', 'St. Augustine', 'OPEN', datetime.date(2014, 1, 3), Decimal('29.924286'), Decimal('-81.416018'))
# (2132, 'USA', 'Murdo', 'OPEN', datetime.date(2013, 12, 31), Decimal('43.886915'), Decimal('-100.716887'))
# (2133, 'USA', 'Santee', 'OPEN', datetime.date(2013, 12, 27), Decimal('33.485858'), Decimal('-80.475763'))
# (2134, 'USA', 'Queens', 'OPEN', datetime.date(2013, 12, 23), Decimal('40.66319'), Decimal('-73.793192'))
# (2135, 'USA', 'Ellensburg', 'OPEN', datetime.date(2013, 12, 23), Decimal('46.976918'), Decimal('-120.54162'))
# (2136, 'USA', 'Detroit', 'OPEN', datetime.date(2013, 12, 23), Decimal('44.737025'), Decimal('-122.152108'))
# (2137, 'USA', 'Lusk', 'OPEN', datetime.date(2013, 12, 19), Decimal('42.75625'), Decimal('-104.45267'))
# (2138, 'USA', 'Vacaville', 'OPEN', datetime.date(2013, 12, 19), Decimal('38.366645'), Decimal('-121.958136'))
# (2139, 'Austria', 'St. Anton am Arlberg', 'OPEN', datetime.date(2013, 12, 19), Decimal('47.130862'), Decimal('10.270811'))
# (2140, 'USA', 'Mitchell', 'OPEN', datetime.date(2013, 12, 18), Decimal('43.701129'), Decimal('-98.04449999999997'))
# (2141, 'Germany', 'Aichstetten', 'OPEN', datetime.date(2013, 12, 14), Decimal('47.880483'), Decimal('10.039783'))
# (2142, 'Germany', 'Bad Rappenau', 'OPEN', datetime.date(2013, 12, 14), Decimal('49.211936'), Decimal('9.077322'))
# (2143, 'Switzerland', 'Lully', 'OPEN', datetime.date(2013, 12, 13), Decimal('46.832137'), Decimal('6.859096'))
# (2144, 'Germany', 'Wilnsdorf', 'OPEN', datetime.date(2013, 12, 13), Decimal('50.816873'), Decimal('8.08576'))
# (2145, 'Germany', 'Jettingen', 'OPEN', datetime.date(2013, 12, 13), Decimal('48.411068'), Decimal('10.440378'))
# (2146, 'USA', 'Worthington', 'OPEN', datetime.date(2013, 12, 11), Decimal('43.63385'), Decimal('-95.595647'))
# (2147, 'USA', 'Mishawaka', 'OPEN', datetime.date(2013, 12, 11), Decimal('41.7174'), Decimal('-86.1887'))
# (2148, 'USA', 'Angola', 'OPEN', datetime.date(2013, 12, 9), Decimal('41.699048'), Decimal('-85.000326'))
# (2149, 'USA', 'Mauston', 'OPEN', datetime.date(2013, 12, 9), Decimal('43.795551'), Decimal('-90.059358'))
# (2150, 'Netherlands', 'Oosterhout', 'OPEN', datetime.date(2013, 12, 6), Decimal('51.626423'), Decimal('4.869517'))
# (2151, 'Netherlands', 'Zevenaar', 'OPEN', datetime.date(2013, 12, 6), Decimal('51.94066'), Decimal('6.0818'))
# (2152, 'USA', 'St. Joseph', 'OPEN', datetime.date(2013, 11, 26), Decimal('42.056357'), Decimal('-86.456352'))
# (2153, 'USA', 'Rapid City', 'OPEN', datetime.date(2013, 11, 25), Decimal('44.105601'), Decimal('-103.212569'))
# (2154, 'USA', 'Huntsville', 'OPEN', datetime.date(2013, 11, 20), Decimal('30.716158'), Decimal('-95.565944'))
# (2155, 'USA', 'Folsom', 'OPEN', datetime.date(2013, 11, 19), Decimal('38.64258'), Decimal('-121.18806'))
# (2156, 'USA', 'Corsicana', 'OPEN', datetime.date(2013, 11, 15), Decimal('32.068577'), Decimal('-96.448229'))
# (2157, 'USA', 'Quartzsite', 'OPEN', datetime.date(2013, 11, 14), Decimal('33.661314'), Decimal('-114.242174'))
# (2158, 'USA', 'Rocky Mount', 'OPEN', datetime.date(2013, 11, 8), Decimal('35.972874'), Decimal('-77.84687'))
# (2159, 'USA', 'Springfield', 'OPEN', datetime.date(2013, 11, 2), Decimal('44.082605'), Decimal('-123.037471'))
# (2160, 'USA', 'Glen Allen', 'OPEN', datetime.date(2013, 10, 24), Decimal('37.669832'), Decimal('-77.461419'))
# (2161, 'USA', 'Mt. Shasta', 'OPEN', datetime.date(2013, 10, 23), Decimal('41.310233'), Decimal('-122.317278'))
# (2162, 'USA', 'Grants Pass', 'OPEN', datetime.date(2013, 10, 22), Decimal('42.460883'), Decimal('-123.324124'))
# (2163, 'USA', 'Corning', 'OPEN', datetime.date(2013, 10, 18), Decimal('39.926454'), Decimal('-122.198393'))
# (2164, 'USA', 'Burlington', 'OPEN', datetime.date(2013, 10, 16), Decimal('36.07079'), Decimal('-79.511211'))
# (2165, 'USA', 'Columbus', 'OPEN', datetime.date(2013, 10, 7), Decimal('29.690062'), Decimal('-96.537725'))
# (2166, 'USA', 'Silverthorne', 'OPEN', datetime.date(2013, 10, 3), Decimal('39.631457'), Decimal('-106.070816'))
# (2167, 'USA', 'Glenwood Springs', 'OPEN', datetime.date(2013, 9, 17), Decimal('39.55268'), Decimal('-107.340168'))
# (2168, 'USA', 'Port Orange', 'OPEN', datetime.date(2013, 9, 13), Decimal('29.108566'), Decimal('-81.034569'))
# (2169, 'USA', 'Rockford', 'OPEN', datetime.date(2013, 9, 12), Decimal('42.243896'), Decimal('-88.978877'))
# (2170, 'USA', 'Bellmead', 'OPEN', datetime.date(2013, 9, 7), Decimal('31.58224'), Decimal('-97.10915'))
# (2171, 'Norway', 'Gol', 'OPEN', datetime.date(2013, 8, 30), Decimal('60.70232'), Decimal('8.9862'))
# (2172, 'Norway', 'Aurland', 'OPEN', datetime.date(2013, 8, 30), Decimal('60.89863'), Decimal('7.21082'))
# (2173, 'Norway', 'Dombås', 'OPEN', datetime.date(2013, 8, 30), Decimal('62.073923'), Decimal('9.125562'))
# (2174, 'Norway', 'Lillehammer', 'OPEN', datetime.date(2013, 8, 30), Decimal('61.13045'), Decimal('10.43491'))
# (2175, 'Norway', 'Lyngdal', 'OPEN', datetime.date(2013, 8, 30), Decimal('58.15653'), Decimal('7.10298'))
# (2176, 'USA', 'Woodburn', 'OPEN', datetime.date(2013, 8, 28), Decimal('45.15313'), Decimal('-122.881254'))
# (2177, 'USA', 'San Marcos', 'OPEN', datetime.date(2013, 8, 17), Decimal('29.827692'), Decimal('-97.979677'))
# (2178, 'USA', 'Fremont', 'OPEN', datetime.date(2013, 8, 16), Decimal('37.492754'), Decimal('-121.944796'))
# (2179, 'Norway', 'Sundebru', 'OPEN', datetime.date(2013, 8, 13), Decimal('58.820783'), Decimal('9.073746'))
# (2180, 'Norway', 'Lier', 'OPEN', datetime.date(2013, 8, 13), Decimal('59.766259'), Decimal('10.257838'))
# (2181, 'USA', 'Fort Myers', 'OPEN', datetime.date(2013, 7, 25), Decimal('26.48564'), Decimal('-81.787136'))
# (2182, 'USA', 'Port St. Lucie', 'OPEN', datetime.date(2013, 7, 24), Decimal('27.313023'), Decimal('-80.406688'))
# (2183, 'USA', 'Centralia', 'OPEN', datetime.date(2013, 7, 17), Decimal('46.729732'), Decimal('-122.977454'))
# (2184, 'USA', 'Buellton', 'OPEN', datetime.date(2013, 7, 13), Decimal('34.61456'), Decimal('-120.188387'))
# (2185, 'USA', 'Burlington', 'OPEN', datetime.date(2013, 7, 13), Decimal('48.509772'), Decimal('-122.338625'))
# (2186, 'USA', 'Atascadero', 'OPEN', datetime.date(2013, 7, 3), Decimal('35.48656'), Decimal('-120.66633'))
# (2187, 'USA', 'Normal', 'OPEN', datetime.date(2013, 6, 26), Decimal('40.508497'), Decimal('-88.985575'))
# (2188, 'USA', 'Darien', 'OPEN', datetime.date(2013, 6, 19), Decimal('41.080321'), Decimal('-73.461365'))
# (2189, 'USA', 'Darien', 'OPEN', datetime.date(2013, 6, 19), Decimal('41.067299'), Decimal('-73.504926'))
# (2190, 'USA', 'Newark', 'OPEN', datetime.date(2012, 12, 21), Decimal('39.6635'), Decimal('-75.69017'))
# (2191, 'USA', 'Milford', 'OPEN', datetime.date(2012, 12, 16), Decimal('41.245814'), Decimal('-73.008988'))
# (2192, 'USA', 'Milford', 'OPEN', datetime.date(2012, 12, 16), Decimal('41.246232'), Decimal('-73.010529'))
# (2193, 'USA', 'Hawthorne', 'OPEN', datetime.date(2012, 11, 19), Decimal('33.921068'), Decimal('-118.330054'))
# (2194, 'USA', 'Barstow', 'OPEN', datetime.date(2012, 11, 19), Decimal('34.849129'), Decimal('-117.085446'))
# (2195, 'USA', 'Gilroy', 'OPEN', datetime.date(2012, 11, 19), Decimal('37.02493'), Decimal('-121.56542'))
# (2196, 'USA', 'Coalinga', 'OPEN', datetime.date(2012, 11, 19), Decimal('36.25415'), Decimal('-120.237896'))
# (2197, 'USA', 'Lebec', 'OPEN', datetime.date(2012, 11, 19), Decimal('34.98734'), Decimal('-118.94623'))

# %%
cursor2 = conn.cursor()
cursor2.execute('SELECT * FROM tsla')
for row in cursor2:
    print(row)
# Out:
# (1, datetime.date(2020, 1, 27), Decimal('111.6'))
# (2, datetime.date(2020, 1, 28), Decimal('113.38'))
# (3, datetime.date(2020, 1, 29), Decimal('116.2'))
# (4, datetime.date(2020, 1, 30), Decimal('128.16'))
# (5, datetime.date(2020, 1, 31), Decimal('130.11'))
# (6, datetime.date(2020, 2, 3), Decimal('156.0'))
# (7, datetime.date(2020, 2, 4), Decimal('177.41'))
# (8, datetime.date(2020, 2, 5), Decimal('146.94'))
# (9, datetime.date(2020, 2, 6), Decimal('149.79'))
# (10, datetime.date(2020, 2, 7), Decimal('149.61'))
# (11, datetime.date(2020, 2, 10), Decimal('154.26'))
# (12, datetime.date(2020, 2, 11), Decimal('154.88'))
# (13, datetime.date(2020, 2, 12), Decimal('153.46'))
# (14, datetime.date(2020, 2, 13), Decimal('160.8'))
# (15, datetime.date(2020, 2, 14), Decimal('160.01'))
# (16, datetime.date(2020, 2, 18), Decimal('171.68'))
# (17, datetime.date(2020, 2, 19), Decimal('183.48'))
# (18, datetime.date(2020, 2, 20), Decimal('179.88'))
# (19, datetime.date(2020, 2, 21), Decimal('180.2'))
# (20, datetime.date(2020, 2, 24), Decimal('166.76'))
# (21, datetime.date(2020, 2, 25), Decimal('159.98'))
# (22, datetime.date(2020, 2, 26), Decimal('155.76'))
# (23, datetime.date(2020, 2, 27), Decimal('135.8'))
# (24, datetime.date(2020, 2, 28), Decimal('133.6'))
# (25, datetime.date(2020, 3, 2), Decimal('148.72'))
# (26, datetime.date(2020, 3, 3), Decimal('149.1'))
# (27, datetime.date(2020, 3, 4), Decimal('149.9'))
# (28, datetime.date(2020, 3, 5), Decimal('144.91'))
# (29, datetime.date(2020, 3, 6), Decimal('140.7'))
# (30, datetime.date(2020, 3, 9), Decimal('121.6'))
# (31, datetime.date(2020, 3, 10), Decimal('129.07'))
# (32, datetime.date(2020, 3, 11), Decimal('126.85'))
# (33, datetime.date(2020, 3, 12), Decimal('112.11'))
# (34, datetime.date(2020, 3, 13), Decimal('109.32'))
# (35, datetime.date(2020, 3, 16), Decimal('89.01'))
# (36, datetime.date(2020, 3, 17), Decimal('86.04'))
# (37, datetime.date(2020, 3, 18), Decimal('72.24'))
# (38, datetime.date(2020, 3, 19), Decimal('85.53'))
# (39, datetime.date(2020, 3, 20), Decimal('85.51'))
# (40, datetime.date(2020, 3, 23), Decimal('86.86'))
# (41, datetime.date(2020, 3, 24), Decimal('101.0'))
# (42, datetime.date(2020, 3, 25), Decimal('107.85'))
# (43, datetime.date(2020, 3, 26), Decimal('105.63'))
# (44, datetime.date(2020, 3, 27), Decimal('102.87'))
# (45, datetime.date(2020, 3, 30), Decimal('100.43'))
# (46, datetime.date(2020, 3, 31), Decimal('104.8'))
# (47, datetime.date(2020, 4, 1), Decimal('96.31'))
# (48, datetime.date(2020, 4, 2), Decimal('90.89'))
# (49, datetime.date(2020, 4, 3), Decimal('96.0'))
# (50, datetime.date(2020, 4, 6), Decimal('103.25'))
# (51, datetime.date(2020, 4, 7), Decimal('109.09'))
# (52, datetime.date(2020, 4, 8), Decimal('109.77'))
# (53, datetime.date(2020, 4, 9), Decimal('114.6'))
# (54, datetime.date(2020, 4, 13), Decimal('130.19'))
# (55, datetime.date(2020, 4, 14), Decimal('141.98'))
# (56, datetime.date(2020, 4, 15), Decimal('145.97'))
# (57, datetime.date(2020, 4, 16), Decimal('149.04'))
# (58, datetime.date(2020, 4, 17), Decimal('150.78'))
# (59, datetime.date(2020, 4, 20), Decimal('149.27'))
# (60, datetime.date(2020, 4, 21), Decimal('137.34'))
# (61, datetime.date(2020, 4, 22), Decimal('146.42'))
# (62, datetime.date(2020, 4, 23), Decimal('141.13'))
# (63, datetime.date(2020, 4, 24), Decimal('145.03'))
# (64, datetime.date(2020, 4, 27), Decimal('159.75'))
# (65, datetime.date(2020, 4, 28), Decimal('153.82'))
# (66, datetime.date(2020, 4, 29), Decimal('160.1'))
# (67, datetime.date(2020, 4, 30), Decimal('156.38'))
# (68, datetime.date(2020, 5, 1), Decimal('140.26'))
# (69, datetime.date(2020, 5, 4), Decimal('152.24'))
# (70, datetime.date(2020, 5, 5), Decimal('153.64'))
# (71, datetime.date(2020, 5, 6), Decimal('156.52'))
# (72, datetime.date(2020, 5, 7), Decimal('156.01'))
# (73, datetime.date(2020, 5, 8), Decimal('163.88'))
# (74, datetime.date(2020, 5, 11), Decimal('162.26'))
# (75, datetime.date(2020, 5, 12), Decimal('161.88'))
# (76, datetime.date(2020, 5, 13), Decimal('158.19'))
# (77, datetime.date(2020, 5, 14), Decimal('160.67'))
# (78, datetime.date(2020, 5, 15), Decimal('159.83'))
# (79, datetime.date(2020, 5, 18), Decimal('162.73'))
# (80, datetime.date(2020, 5, 19), Decimal('161.6'))
# (81, datetime.date(2020, 5, 20), Decimal('163.11'))
# (82, datetime.date(2020, 5, 21), Decimal('165.52'))
# (83, datetime.date(2020, 5, 22), Decimal('163.38'))
# (84, datetime.date(2020, 5, 26), Decimal('163.77'))
# (85, datetime.date(2020, 5, 27), Decimal('164.05'))
# (86, datetime.date(2020, 5, 28), Decimal('161.16'))
# (87, datetime.date(2020, 5, 29), Decimal('167.0'))
# (88, datetime.date(2020, 6, 1), Decimal('179.62'))
# (89, datetime.date(2020, 6, 2), Decimal('176.31'))
# (90, datetime.date(2020, 6, 3), Decimal('176.59'))
# (91, datetime.date(2020, 6, 4), Decimal('172.88'))
# (92, datetime.date(2020, 6, 5), Decimal('177.13'))
# (93, datetime.date(2020, 6, 8), Decimal('189.98'))
# (94, datetime.date(2020, 6, 9), Decimal('188.13'))
# (95, datetime.date(2020, 6, 10), Decimal('205.01'))
# (96, datetime.date(2020, 6, 11), Decimal('194.57'))
# (97, datetime.date(2020, 6, 12), Decimal('187.06'))
# (98, datetime.date(2020, 6, 15), Decimal('198.18'))
# (99, datetime.date(2020, 6, 16), Decimal('196.43'))
# (100, datetime.date(2020, 6, 17), Decimal('198.36'))
# (101, datetime.date(2020, 6, 18), Decimal('200.79'))
# (102, datetime.date(2020, 6, 19), Decimal('200.18'))
# (103, datetime.date(2020, 6, 22), Decimal('198.86'))
# (104, datetime.date(2020, 6, 23), Decimal('200.36'))
# (105, datetime.date(2020, 6, 24), Decimal('192.17'))
# (106, datetime.date(2020, 6, 25), Decimal('197.2'))
# (107, datetime.date(2020, 6, 26), Decimal('191.95'))
# (108, datetime.date(2020, 6, 29), Decimal('201.87'))
# (109, datetime.date(2020, 6, 30), Decimal('215.96'))
# (110, datetime.date(2020, 7, 1), Decimal('223.93'))
# (111, datetime.date(2020, 7, 2), Decimal('241.73'))
# (112, datetime.date(2020, 7, 6), Decimal('274.32'))
# (113, datetime.date(2020, 7, 7), Decimal('277.97'))
# (114, datetime.date(2020, 7, 8), Decimal('273.18'))
# (115, datetime.date(2020, 7, 9), Decimal('278.86'))
# (116, datetime.date(2020, 7, 10), Decimal('308.93'))
# (117, datetime.date(2020, 7, 13), Decimal('299.41'))
# (118, datetime.date(2020, 7, 14), Decimal('303.36'))
# (119, datetime.date(2020, 7, 15), Decimal('309.2'))
# (120, datetime.date(2020, 7, 16), Decimal('300.13'))
# (121, datetime.date(2020, 7, 17), Decimal('300.17'))
# (122, datetime.date(2020, 7, 20), Decimal('328.6'))
# (123, datetime.date(2020, 7, 21), Decimal('313.67'))
# (124, datetime.date(2020, 7, 22), Decimal('318.47'))
# (125, datetime.date(2020, 7, 23), Decimal('302.61'))
# (126, datetime.date(2020, 7, 24), Decimal('283.4'))
# (127, datetime.date(2020, 7, 27), Decimal('307.92'))
# (128, datetime.date(2020, 7, 28), Decimal('295.3'))
# (129, datetime.date(2020, 7, 29), Decimal('299.82'))
# (130, datetime.date(2020, 7, 30), Decimal('297.5'))
# (131, datetime.date(2020, 7, 31), Decimal('286.15'))
# (132, datetime.date(2020, 8, 3), Decimal('297.0'))
# (133, datetime.date(2020, 8, 4), Decimal('297.4'))
# (134, datetime.date(2020, 8, 5), Decimal('297.0'))
# (135, datetime.date(2020, 8, 6), Decimal('297.92'))
# (136, datetime.date(2020, 8, 7), Decimal('290.54'))
# (137, datetime.date(2020, 8, 10), Decimal('283.71'))
# (138, datetime.date(2020, 8, 11), Decimal('274.88'))
# (139, datetime.date(2020, 8, 12), Decimal('310.95'))
# (140, datetime.date(2020, 8, 13), Decimal('324.2'))
# (141, datetime.date(2020, 8, 14), Decimal('330.14'))
# (142, datetime.date(2020, 8, 17), Decimal('367.13'))
# (143, datetime.date(2020, 8, 18), Decimal('377.42'))
# (144, datetime.date(2020, 8, 19), Decimal('375.71'))
# (145, datetime.date(2020, 8, 20), Decimal('400.37'))
# (146, datetime.date(2020, 8, 21), Decimal('410.0'))
# (147, datetime.date(2020, 8, 24), Decimal('402.84'))
# (148, datetime.date(2020, 8, 25), Decimal('404.67'))
# (149, datetime.date(2020, 8, 26), Decimal('430.63'))
# (150, datetime.date(2020, 8, 27), Decimal('447.75'))
# (151, datetime.date(2020, 8, 28), Decimal('442.68'))
# (152, datetime.date(2020, 8, 31), Decimal('498.32'))
# (153, datetime.date(2020, 9, 1), Decimal('475.05'))
# (154, datetime.date(2020, 9, 2), Decimal('447.37'))
# (155, datetime.date(2020, 9, 3), Decimal('407.0'))
# (156, datetime.date(2020, 9, 4), Decimal('418.32'))
# (157, datetime.date(2020, 9, 8), Decimal('330.21'))
# (158, datetime.date(2020, 9, 9), Decimal('366.28'))
# (159, datetime.date(2020, 9, 10), Decimal('371.34'))
# (160, datetime.date(2020, 9, 11), Decimal('372.72'))
# (161, datetime.date(2020, 9, 14), Decimal('419.62'))
# (162, datetime.date(2020, 9, 15), Decimal('449.76'))
# (163, datetime.date(2020, 9, 16), Decimal('441.76'))
# (164, datetime.date(2020, 9, 17), Decimal('423.43'))
# (165, datetime.date(2020, 9, 18), Decimal('442.15'))
# (166, datetime.date(2020, 9, 21), Decimal('449.39'))
# (167, datetime.date(2020, 9, 22), Decimal('424.23'))
# (168, datetime.date(2020, 9, 23), Decimal('380.36'))
# (169, datetime.date(2020, 9, 24), Decimal('387.79'))
# (170, datetime.date(2020, 9, 25), Decimal('407.34'))
# (171, datetime.date(2020, 9, 28), Decimal('421.2'))
# (172, datetime.date(2020, 9, 29), Decimal('419.07'))
# (173, datetime.date(2020, 9, 30), Decimal('429.01'))
# (174, datetime.date(2020, 10, 1), Decimal('448.16'))
# (175, datetime.date(2020, 10, 2), Decimal('415.09'))
# (176, datetime.date(2020, 10, 5), Decimal('425.68'))
# (177, datetime.date(2020, 10, 6), Decimal('413.98'))
# (178, datetime.date(2020, 10, 7), Decimal('425.3'))
# (179, datetime.date(2020, 10, 8), Decimal('425.92'))
# (180, datetime.date(2020, 10, 9), Decimal('434.0'))
# (181, datetime.date(2020, 10, 12), Decimal('442.3'))
# (182, datetime.date(2020, 10, 13), Decimal('446.65'))
# (183, datetime.date(2020, 10, 14), Decimal('461.3'))
# (184, datetime.date(2020, 10, 15), Decimal('448.88'))
# (185, datetime.date(2020, 10, 16), Decimal('439.67'))
# (186, datetime.date(2020, 10, 19), Decimal('430.83'))
# (187, datetime.date(2020, 10, 20), Decimal('421.94'))
# (188, datetime.date(2020, 10, 21), Decimal('422.64'))
# (189, datetime.date(2020, 10, 22), Decimal('425.79'))
# (190, datetime.date(2020, 10, 23), Decimal('420.63'))
# (191, datetime.date(2020, 10, 26), Decimal('420.28'))
# (192, datetime.date(2020, 10, 27), Decimal('424.68'))
# (193, datetime.date(2020, 10, 28), Decimal('406.02'))
# (194, datetime.date(2020, 10, 29), Decimal('410.83'))
# (195, datetime.date(2020, 10, 30), Decimal('388.04'))
# (196, datetime.date(2020, 11, 2), Decimal('400.51'))
# (197, datetime.date(2020, 11, 3), Decimal('423.9'))
# (198, datetime.date(2020, 11, 4), Decimal('420.98'))
# (199, datetime.date(2020, 11, 5), Decimal('438.09'))
# (200, datetime.date(2020, 11, 6), Decimal('429.95'))
# (201, datetime.date(2020, 11, 9), Decimal('421.26'))
# (202, datetime.date(2020, 11, 10), Decimal('410.36'))
# (203, datetime.date(2020, 11, 11), Decimal('417.13'))
# (204, datetime.date(2020, 11, 12), Decimal('411.76'))
# (205, datetime.date(2020, 11, 13), Decimal('408.5'))
# (206, datetime.date(2020, 11, 16), Decimal('408.09'))
# (207, datetime.date(2020, 11, 17), Decimal('441.61'))
# (208, datetime.date(2020, 11, 18), Decimal('486.64'))
# (209, datetime.date(2020, 11, 19), Decimal('499.27'))
# (210, datetime.date(2020, 11, 20), Decimal('489.61'))
# (211, datetime.date(2020, 11, 23), Decimal('521.85'))
# (212, datetime.date(2020, 11, 24), Decimal('555.38'))
# (213, datetime.date(2020, 11, 25), Decimal('574.0'))
# (214, datetime.date(2020, 11, 27), Decimal('585.76'))
# (215, datetime.date(2020, 11, 30), Decimal('567.6'))
# (216, datetime.date(2020, 12, 1), Decimal('584.76'))
# (217, datetime.date(2020, 12, 2), Decimal('568.82'))
# (218, datetime.date(2020, 12, 3), Decimal('593.38'))
# (219, datetime.date(2020, 12, 4), Decimal('599.04'))
# (220, datetime.date(2020, 12, 7), Decimal('641.76'))
# (221, datetime.date(2020, 12, 8), Decimal('649.88'))
# (222, datetime.date(2020, 12, 9), Decimal('604.48'))
# (223, datetime.date(2020, 12, 10), Decimal('627.07'))
# (224, datetime.date(2020, 12, 11), Decimal('609.99'))
# (225, datetime.date(2020, 12, 14), Decimal('639.83'))
# (226, datetime.date(2020, 12, 15), Decimal('633.25'))
# (227, datetime.date(2020, 12, 16), Decimal('622.77'))
# (228, datetime.date(2020, 12, 17), Decimal('655.9'))
# (229, datetime.date(2020, 12, 18), Decimal('695.0'))
# (230, datetime.date(2020, 12, 21), Decimal('649.86'))
# (231, datetime.date(2020, 12, 22), Decimal('640.34'))
# (232, datetime.date(2020, 12, 23), Decimal('645.98'))
# (233, datetime.date(2020, 12, 24), Decimal('661.77'))
# (234, datetime.date(2020, 12, 28), Decimal('663.69'))
# (235, datetime.date(2020, 12, 29), Decimal('665.99'))
# (236, datetime.date(2020, 12, 30), Decimal('694.78'))
# (237, datetime.date(2020, 12, 31), Decimal('705.67'))
# (238, datetime.date(2021, 1, 4), Decimal('729.77'))
# (239, datetime.date(2021, 1, 5), Decimal('735.11'))
# (240, datetime.date(2021, 1, 6), Decimal('755.98'))
# (241, datetime.date(2021, 1, 7), Decimal('816.04'))
# (242, datetime.date(2021, 1, 8), Decimal('880.02'))
# (243, datetime.date(2021, 1, 11), Decimal('811.19'))
# (244, datetime.date(2021, 1, 12), Decimal('849.44'))
# (245, datetime.date(2021, 1, 13), Decimal('854.41'))
# (246, datetime.date(2021, 1, 14), Decimal('845.0'))
# (247, datetime.date(2021, 1, 15), Decimal('826.16'))
# (248, datetime.date(2021, 1, 19), Decimal('844.55'))
# (249, datetime.date(2021, 1, 20), Decimal('850.45'))
# (250, datetime.date(2021, 1, 21), Decimal('844.99'))
# (251, datetime.date(2021, 1, 22), Decimal('846.64'))
# (252, datetime.date(2021, 1, 25), Decimal('880.8'))

# %%
#flask app time

# %%
app = Flask(__name__)

# %%
@app.route("/")
def read():
    cursor1.execute('SELECT * FROM supercharged')
    id_list = []
    for row in cursor1:
        id_list.append(row)
    cursor2.execute('SELECT * FROM tsla')
    id_list2 =[]
    for row in cursor2:
        id_list2.append(row)
    return render_template("index.html",id_list2=id_list2,id_list=id_list)

# %%
if __name__ = "__main__":
    app.run(debug=True)
# Out:
#   File "<ipython-input-40-f30b3e2556e5>", line 1
#     if __name__ = "__main__":
#                 ^
# SyntaxError: invalid syntax
